# %% [markdown]
# #**Read me**

# %% [markdown]
# El enfoque de este proyecto es emplear ML no supervisado, por lo que no se busco un dataset de galaxias etiquetado. Las imagenes (jpg) fuero obtenida de la plataforma [zoo galaxy](https://data.galaxyzoo.org/#section-21) correspondientes al Galaxy Zoo 2 ([images_gz2.zip](https://zenodo.org/records/3565489#.Y3vFKS-l0eY)).
#
# Se tomaron aleatoriamente 10,000 imgenes (jpg) para entrenar y 5,000 (jpg) para hacer pruebas, el uso de 15,000 archivos diferentes no es practica, por lo que es preciso vertir las imagenes en un archivo que las contenga de una manera más portable.
#
# Aun asi, se mantendra el [acceso directo](https://drive.google.com/drive/folders/19dFtIuN5AJwEbsUqUL_6RZT1T1TBEMnY?usp=drive_link) a las imagenes jpg empleadas en el proyecto.
#
# En estec codigo se muestra como convertir las 15,000 imagenes ".jpg" en archivos ".h5" orgnizandolos en dos archivos, para entrenar y probar, además de como guardarlo en drive

# %% [markdown]
# # Set up

# %% [markdown]
# ## Package

# %%
# Mount Google Drive to access and store files
# Comment out this cell if running the script locally

from google.colab import drive
drive.mount('/content/drive', force_remount=True)  # Force remount to ensure access
# Out:
# Mounted at /content/drive

# %%
import os

import h5py

import time

from PIL import Image

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Directories

# %%
# Define basic configuration for data usage
DATA_USAGE = ['Train', 'Test']  # Specifies the dataset categories (training and testing)

# Paths for storing data
ROOT_JPGS = '/content/drive/MyDrive/Practicas_Profesionales/Data/JPGs'  # Directory for storing JPG image files
ROOT_H5S = '/content/drive/MyDrive/Practicas_Profesionales/Data/H5s'  # Directory for storing HDF5 (H5) data files

# %% [markdown]
# #Conver JPG to H5

# %%
indx = 0  # Index to select the dataset type (0 = 'Train', 1 = 'Test')

# Construct the path to the selected dataset (e.g., training images)
root_data = os.path.join(ROOT_JPGS, DATA_USAGE[indx])

# List all JPG images in the selected directory
imgs_jpg = os.listdir(root_data)

# %%
cuenta = 0  # Counter to track the number of processed images

print(f'Data extracted: {DATA_USAGE[indx]}')  # Display the dataset being processed
start_time = time.time()  # Start time for performance measurement

# Iterate through all images in the selected dataset
for i in range(len(imgs_jpg)):

  # Extract the image name without the file extension
  name = imgs_jpg[i][:-4]

  # Define the corresponding HDF5 file path
  name_fileh5 = os.path.join(ROOT_H5S, DATA_USAGE[indx]) + '/' + name + '.h5'

  # Get the full path to the current image
  root_img = os.path.join(root_data, imgs_jpg[i])

  # Open and convert the image to a NumPy array
  with Image.open(root_img) as img_jpg:
      img_array = np.array(img_jpg)

  # Save the image data in an HDF5 file with compression
  with h5py.File(name_fileh5, 'w') as f:
      f.create_dataset("number", data=np.array(int(name), dtype=np.int32))  # Store image number
      f.create_dataset("galaxy", data=img_array, compression="gzip", compression_opts=9)  # Store image data with compression

  cuenta += 1  # Update counter

  # Display progress every 250 images
  if cuenta % 250 == 0:
      delta_t = time.time() - start_time  # Calculate elapsed time
      print(f'Progress: {np.round(cuenta / len(imgs_jpg) * 100, 4)}%\nExecution Time: {delta_t:.2f} s\n')
# Out:
# Datos extraidos: Train
# Progreso: 2.5%
# Tiempo de ejecución: 227.56 s
#
# Progreso: 5.0%
# Tiempo de ejecución: 255.09 s
#
# Progreso: 7.5%
# Tiempo de ejecución: 277.77 s
#
# Progreso: 10.0%
# Tiempo de ejecución: 297.84 s
#
# Progreso: 12.5%
# Tiempo de ejecución: 319.27 s
#
# Progreso: 15.0%
# Tiempo de ejecución: 343.18 s
#
# Progreso: 17.5%
# Tiempo de ejecución: 365.43 s
#
# Progreso: 20.0%
# Tiempo de ejecución: 387.95 s
#
# Progreso: 22.5%
# Tiempo de ejecución: 409.89 s
#
# Progreso: 25.0%
# Tiempo de ejecución: 433.12 s
#
# Progreso: 27.5%
# Tiempo de ejecución: 458.37 s
#
# Progreso: 30.0%
# Tiempo de ejecución: 482.59 s
#
# Progreso: 32.5%
# Tiempo de ejecución: 507.68 s
#
# Progreso: 35.0%
# Tiempo de ejecución: 532.54 s
#
# Progreso: 37.5%
# Tiempo de ejecución: 557.89 s
#
# Progreso: 40.0%
# Tiempo de ejecución: 580.58 s
#
# Progreso: 42.5%
# Tiempo de ejecución: 604.53 s
#
# Progreso: 45.0%
# Tiempo de ejecución: 627.77 s
#
# Progreso: 47.5%
# Tiempo de ejecución: 653.59 s
#
# Progreso: 50.0%
# Tiempo de ejecución: 679.05 s
#
# Progreso: 52.5%
# Tiempo de ejecución: 703.07 s
#
# Progreso: 55.0%
# Tiempo de ejecución: 725.99 s
#
# Progreso: 57.5%
# Tiempo de ejecución: 748.06 s
#
# Progreso: 60.0%
# Tiempo de ejecución: 771.29 s
#
# Progreso: 62.5%
# Tiempo de ejecución: 792.47 s
#
# Progreso: 65.0%
# Tiempo de ejecución: 816.32 s
#
# Progreso: 67.5%
# Tiempo de ejecución: 838.75 s
#
# Progreso: 70.0%
# Tiempo de ejecución: 867.01 s
#
# Progreso: 72.5%
# Tiempo de ejecución: 889.68 s
#
# Progreso: 75.0%
# Tiempo de ejecución: 912.54 s
#
# Progreso: 77.5%
# Tiempo de ejecución: 933.97 s
#
# Progreso: 80.0%
# Tiempo de ejecución: 957.99 s
#
# Progreso: 82.5%
# Tiempo de ejecución: 981.65 s
#
# Progreso: 85.0%
# Tiempo de ejecución: 1005.08 s
#
# Progreso: 87.5%
# Tiempo de ejecución: 1028.74 s
#
# Progreso: 90.0%
# Tiempo de ejecución: 1052.25 s
#
# Progreso: 92.5%
# Tiempo de ejecución: 1074.62 s
#
# Progreso: 95.0%
# Tiempo de ejecución: 1095.46 s
#
# Progreso: 97.5%
# Tiempo de ejecución: 1116.12 s
#
# Progreso: 100.0%
# Tiempo de ejecución: 1137.85 s

# %% [markdown]
# ##Check Files saved

# %%
# Define the directory containing the HDF5 files for the selected dataset (Train or Test)
data_dir = os.path.join(ROOT_H5S, DATA_USAGE[indx])

# Select a specific HDF5 file (in this case, the 9th file in the list)
cheack_file = os.listdir(data_dir)[8]  # Possible typo in variable name: "cheack_file" -> "check_file"

# Construct the full path to the selected HDF5 file
name_file = os.path.join(data_dir, cheack_file)

# Start timing the file reading process
start_time = time.time()

# Open and read the selected HDF5 file
with h5py.File(name_file, 'r') as f:
    imagenes = f["galaxy"][:]  # Load image data
    imagenes_nombres = f["number"][()]  # Load image identifier

# Print the time taken to read the file
print((time.time() - start_time))
# Out:
# 0.31943821907043457

# %% [markdown]
# #File compression

# %% [markdown]
# ##H5 Files

# %%
# Compress all .h5 files into a single archive
# This process is done separately for both Train and Test datasets

indx = 1  # Select dataset to compress [0 = Train, 1 = Test]

# Define the directory containing the HDF5 files for the selected dataset
data_dir = os.path.join(ROOT_H5S, DATA_USAGE[indx])

# Define the output compressed file path (Train.tar.gz or Test.tar.gz)
tar_file = os.path.join(ROOT_H5S, f"{DATA_USAGE[indx]}.tar.gz")

# Create a compressed tar archive (.tar.gz) containing all files in the selected directory
# !tar -czvf "{tar_file}" -C "{data_dir}" .
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# ./140592.h5
# tar: ./140592.h5: file changed as we read it
# ./140676.h5
# tar: ./140676.h5: file changed as we read it
# ./140776.h5
# tar: ./140776.h5: file changed as we read it
# ./140835.h5
# tar: ./140835.h5: file changed as we read it
# ./140839.h5
# tar: ./140839.h5: file changed as we read it
# ./140852.h5
# ./140855.h5
# tar: ./140855.h5: file changed as we read it
# ./140877.h5
# tar: ./140877.h5: file changed as we read it
# ./140971.h5
# tar: ./140971.h5: file changed as we read it
# ./140992.h5
# tar: ./140992.h5: file changed as we read it
# ./141004.h5
# tar: ./141004.h5: file changed as we read it
# ./141066.h5
# tar: ./141066.h5: file changed as we read it
# ./141078.h5
# tar: ./141078.h5: file changed as we read it
# ./141080.h5
# tar: ./141080.h5: file changed as we read it
# ./141136.h5
# tar: ./141136.h5: file changed as we read it
# ./141161.h5
# tar: ./141161.h5: file changed as we read it
# ./141240.h5
# tar: ./141240.h5: file changed as we read it
# ./141294.h5
# tar: ./141294.h5: file changed as we read it
# ./141329.h5
# tar: ./141329.h5: file changed as we read it
# ./141333.h5
# tar: ./141333.h5: file changed as we read it
# ./141340.h5
# tar: ./141340.h5: file changed as we read it
# ./141473.h5
# tar: ./141473.h5: file changed as we read it
# ./141512.h5
# tar: ./141512.h5: file changed as we read it
# ./141516.h5
# tar: ./141516.h5: file changed as we read it
# ./141582.h5
# tar: ./141582.h5: file changed as we read it
# ./141628.h5
# tar: ./141628.h5: file changed as we read it
# ./141742.h5
# tar: ./141742.h5: file changed as we read it
# ./141768.h5
# tar: ./141768.h5: file changed as we read it
# ./141773.h5
# tar: ./141773.h5: file changed as we read it
# ./141884.h5
# tar: ./141884.h5: file changed as we read it
# ./141894.h5
# tar: ./141894.h5: file changed as we read it
# ./142109.h5
# tar: ./142109.h5: file changed as we read it
# ./142117.h5
# tar: ./142117.h5: file changed as we read it
# ./142169.h5
# tar: ./142169.h5: file changed as we read it
# ./142225.h5
# tar: ./142225.h5: file changed as we read it
# ./142236.h5
# tar: ./142236.h5: file changed as we read it
# ./142597.h5
# tar: ./142597.h5: file changed as we read it
# ./142618.h5
# tar: ./142618.h5: file changed as we read it
# ./142647.h5
# tar: ./142647.h5: file changed as we read it
# ./142750.h5
# tar: ./142750.h5: file changed as we read it
# ./142819.h5
# tar: ./142819.h5: file changed as we read it
# ./142820.h5
# tar: ./142820.h5: file changed as we read it
# ./142981.h5
# tar: ./142981.h5: file changed as we read it
# ./143054.h5
# tar: ./143054.h5: file changed as we read it
# ./143063.h5
# tar: ./143063.h5: file changed as we read it
# ./143101.h5
# tar: ./143101.h5: file changed as we read it
# ./143105.h5
# tar: ./143105.h5: file changed as we read it
# ./143112.h5
# tar: ./143112.h5: file changed as we read it
# ./143153.h5
# tar: ./143153.h5: file changed as we read it
# ./143222.h5
# tar: ./143222.h5: file changed as we read it
# ./143283.h5
# tar: ./143283.h5: file changed as we read it
# ./143291.h5
# tar: ./143291.h5: file changed as we read it
# ./143392.h5
# tar: ./143392.h5: file changed as we read it
# ./143408.h5
# tar: ./143408.h5: file changed as we read it
# ./143443.h5
# tar: ./143443.h5: file changed as we read it
# ./143641.h5
# tar: ./143641.h5: file changed as we read it
# ./143742.h5
# tar: ./143742.h5: file changed as we read it
# ./143746.h5
# tar: ./143746.h5: file changed as we read it
# ./143750.h5
# tar: ./143750.h5: file changed as we read it
# ./143864.h5
# tar: ./143864.h5: file changed as we read it
# ./143896.h5
# tar: ./143896.h5: file changed as we read it
# ./143918.h5
# tar: ./143918.h5: file changed as we read it
# ./143923.h5
# tar: ./143923.h5: file changed as we read it
# ./143973.h5
# tar: ./143973.h5: file changed as we read it
# ./144023.h5
# tar: ./144023.h5: file changed as we read it
# ./144035.h5
# tar: ./144035.h5: file changed as we read it
# ./144115.h5
# tar: ./144115.h5: file changed as we read it
# ./144153.h5
# tar: ./144153.h5: file changed as we read it
# ./144281.h5
# tar: ./144281.h5: file changed as we read it
# ./144282.h5
# tar: ./144282.h5: file changed as we read it
# ./144348.h5
# tar: ./144348.h5: file changed as we read it
# ./144356.h5
# tar: ./144356.h5: file changed as we read it
# ./144653.h5
# tar: ./144653.h5: file changed as we read it
# ./144695.h5
# tar: ./144695.h5: file changed as we read it
# ./144892.h5
# tar: ./144892.h5: file changed as we read it
# ./144935.h5
# tar: ./144935.h5: file changed as we read it
# ./144955.h5
# tar: ./144955.h5: file changed as we read it
# ./144992.h5
# tar: ./144992.h5: file changed as we read it
# ./145066.h5
# tar: ./145066.h5: file changed as we read it
# ./145128.h5
# tar: ./145128.h5: file changed as we read it
# ./145186.h5
# tar: ./145186.h5: file changed as we read it
# ./145216.h5
# tar: ./145216.h5: file changed as we read it
# ./145339.h5
# tar: ./145339.h5: file changed as we read it
# ./145401.h5
# tar: ./145401.h5: file changed as we read it
# ./145433.h5
# tar: ./145433.h5: file changed as we read it
# ./145572.h5
# tar: ./145572.h5: file changed as we read it
# ./145587.h5
# tar: ./145587.h5: file changed as we read it
# ./145644.h5
# tar: ./145644.h5: file changed as we read it
# ./148018.h5
# tar: ./148018.h5: file changed as we read it
# ./148021.h5
# tar: ./148021.h5: file changed as we read it
# ./148095.h5
# tar: ./148095.h5: file changed as we read it
# ./148096.h5
# tar: ./148096.h5: file changed as we read it
# ./148166.h5
# tar: ./148166.h5: file changed as we read it
# ./148182.h5
# tar: ./148182.h5: file changed as we read it
# ./148201.h5
# tar: ./148201.h5: file changed as we read it
# ./148285.h5
# tar: ./148285.h5: file changed as we read it
# ./148291.h5
# tar: ./148291.h5: file changed as we read it
# ./148347.h5
# tar: ./148347.h5: file changed as we read it
# ./148357.h5
# tar: ./148357.h5: file changed as we read it
# ./148384.h5
# tar: ./148384.h5: file changed as we read it
# ./148507.h5
# tar: ./148507.h5: file changed as we read it
# ./148629.h5
# tar: ./148629.h5: file changed as we read it
# ./148661.h5
# tar: ./148661.h5: file changed as we read it
# ./148726.h5
# tar: ./148726.h5: file changed as we read it
# ./148733.h5
# tar: ./148733.h5: file changed as we read it
# ./148747.h5
# tar: ./148747.h5: file changed as we read it
# ./148774.h5
# tar: ./148774.h5: file changed as we read it
# ./148804.h5
# tar: ./148804.h5: file changed as we read it
# ./148856.h5
# tar: ./148856.h5: file changed as we read it
# ./148874.h5
# tar: ./148874.h5: file changed as we read it
# ./148875.h5
# tar: ./148875.h5: file changed as we read it
# ./148899.h5
# tar: ./148899.h5: file changed as we read it
# ./148918.h5
# tar: ./148918.h5: file changed as we read it
# ./148924.h5
# tar: ./148924.h5: file changed as we read it
# ./148977.h5
# tar: ./148977.h5: file changed as we read it
# ./149018.h5
# tar: ./149018.h5: file changed as we read it
# ./149053.h5
# tar: ./149053.h5: file changed as we read it
# ./149070.h5
# tar: ./149070.h5: file changed as we read it
# ./149127.h5
# tar: ./149127.h5: file changed as we read it
# ./149176.h5
# tar: ./149176.h5: file changed as we read it
# ./149184.h5
# tar: ./149184.h5: file changed as we read it
# ./149200.h5
# tar: ./149200.h5: file changed as we read it
# ./149236.h5
# tar: ./149236.h5: file changed as we read it
# ./149383.h5
# tar: ./149383.h5: file changed as we read it
# ./149390.h5
# tar: ./149390.h5: file changed as we read it
# ./149435.h5
# tar: ./149435.h5: file changed as we read it
# ./149521.h5
# tar: ./149521.h5: file changed as we read it
# ./149567.h5
# tar: ./149567.h5: file changed as we read it
# ./149630.h5
# tar: ./149630.h5: file changed as we read it
# ./149781.h5
# tar: ./149781.h5: file changed as we read it
# ./149820.h5
# tar: ./149820.h5: file changed as we read it
# ./149832.h5
# tar: ./149832.h5: file changed as we read it
# ./149838.h5
# tar: ./149838.h5: file changed as we read it
# ./149904.h5
# tar: ./149904.h5: file changed as we read it
# ./149912.h5
# tar: ./149912.h5: file changed as we read it
# ./149943.h5
# tar: ./149943.h5: file changed as we read it
# ./149954.h5
# tar: ./149954.h5: file changed as we read it
# ./150042.h5
# tar: ./150042.h5: file changed as we read it
# ./150163.h5
# tar: ./150163.h5: file changed as we read it
# ./150285.h5
# ./150304.h5
# tar: ./150304.h5: file changed as we read it
# ./150432.h5
# tar: ./150432.h5: file changed as we read it
# ./150442.h5
# tar: ./150442.h5: file changed as we read it
# ./150507.h5
# tar: ./150507.h5: file changed as we read it
# ./150547.h5
# tar: ./150547.h5: file changed as we read it
# ./150559.h5
# tar: ./150559.h5: file changed as we read it
# ./150573.h5
# tar: ./150573.h5: file changed as we read it
# ./150607.h5
# tar: ./150607.h5: file changed as we read it
# ./150619.h5
# tar: ./150619.h5: file changed as we read it
# ./150629.h5
# tar: ./150629.h5: file changed as we read it
# ./150664.h5
# tar: ./150664.h5: file changed as we read it
# ./150699.h5
# tar: ./150699.h5: file changed as we read it
# ./150750.h5
# tar: ./150750.h5: file changed as we read it
# ./150812.h5
# tar: ./150812.h5: file changed as we read it
# ./150851.h5
# tar: ./150851.h5: file changed as we read it
# ./150883.h5
# tar: ./150883.h5: file changed as we read it
# ./150889.h5
# tar: ./150889.h5: file changed as we read it
# ./150945.h5
# tar: ./150945.h5: file changed as we read it
# ./150957.h5
# ./151026.h5
# tar: ./151026.h5: file changed as we read it
# ./151093.h5
# tar: ./151093.h5: file changed as we read it
# ./151192.h5
# tar: ./151192.h5: file changed as we read it
# ./151197.h5
# tar: ./151197.h5: file changed as we read it
# ./151202.h5
# tar: ./151202.h5: file changed as we read it
# ./151236.h5
# tar: ./151236.h5: file changed as we read it
# ./151266.h5
# tar: ./151266.h5: file changed as we read it
# ./151300.h5
# ./151307.h5
# ./151317.h5
# tar: ./151317.h5: file changed as we read it
# ./151331.h5
# tar: ./151331.h5: file changed as we read it
# ./151349.h5
# tar: ./151349.h5: file changed as we read it
# ./151351.h5
# tar: ./151351.h5: file changed as we read it
# ./151378.h5
# tar: ./151378.h5: file changed as we read it
# ./151511.h5
# tar: ./151511.h5: file changed as we read it
# ./151597.h5
# tar: ./151597.h5: file changed as we read it
# ./151619.h5
# tar: ./151619.h5: file changed as we read it
# ./151627.h5
# tar: ./151627.h5: file changed as we read it
# ./151672.h5
# tar: ./151672.h5: file changed as we read it
# ./151692.h5
# tar: ./151692.h5: file changed as we read it
# ./151701.h5
# tar: ./151701.h5: file changed as we read it
# ./151745.h5
# tar: ./151745.h5: file changed as we read it
# ./151750.h5
# tar: ./151750.h5: file changed as we read it
# ./151844.h5
# tar: ./151844.h5: file changed as we read it
# ./151856.h5
# tar: ./151856.h5: file changed as we read it
# ./151947.h5
# tar: ./151947.h5: file changed as we read it
# ./151955.h5
# tar: ./151955.h5: file changed as we read it
# ./152050.h5
# tar: ./152050.h5: file changed as we read it
# ./152060.h5
# tar: ./152060.h5: file changed as we read it
# ./152153.h5
# tar: ./152153.h5: file changed as we read it
# ./152189.h5
# tar: ./152189.h5: file changed as we read it
# ./152327.h5
# tar: ./152327.h5: file changed as we read it
# ./152502.h5
# tar: ./152502.h5: file changed as we read it
# ./152545.h5
# tar: ./152545.h5: file changed as we read it
# ./152625.h5
# tar: ./152625.h5: file changed as we read it
# ./152728.h5
# tar: ./152728.h5: file changed as we read it
# ./152740.h5
# tar: ./152740.h5: file changed as we read it
# ./153002.h5
# tar: ./153002.h5: file changed as we read it
# ./153068.h5
# tar: ./153068.h5: file changed as we read it
# ./153094.h5
# tar: ./153094.h5: file changed as we read it
# ./153132.h5
# tar: ./153132.h5: file changed as we read it
# ./153269.h5
# tar: ./153269.h5: file changed as we read it
# ./153280.h5
# tar: ./153280.h5: file changed as we read it
# ./153381.h5
# tar: ./153381.h5: file changed as we read it
# ./153415.h5
# tar: ./153415.h5: file changed as we read it
# ./153418.h5
# tar: ./153418.h5: file changed as we read it
# ./153505.h5
# tar: ./153505.h5: file changed as we read it
# ./153511.h5
# tar: ./153511.h5: file changed as we read it
# ./153586.h5
# tar: ./153586.h5: file changed as we read it
# ./153782.h5
# tar: ./153782.h5: file changed as we read it
# ./153846.h5
# tar: ./153846.h5: file changed as we read it
# ./153853.h5
# tar: ./153853.h5: file changed as we read it
# ./153980.h5
# tar: ./153980.h5: file changed as we read it
# ./154079.h5
# tar: ./154079.h5: file changed as we read it
# ./154106.h5
# tar: ./154106.h5: file changed as we read it
# ./154124.h5
# tar: ./154124.h5: file changed as we read it
# ./154144.h5
# tar: ./154144.h5: file changed as we read it
# ./154254.h5
# tar: ./154254.h5: file changed as we read it
# ./154275.h5
# tar: ./154275.h5: file changed as we read it
# ./154313.h5
# tar: ./154313.h5: file changed as we read it
# ./154397.h5
# tar: ./154397.h5: file changed as we read it
# ./154416.h5
# tar: ./154416.h5: file changed as we read it
# ./154496.h5
# tar: ./154496.h5: file changed as we read it
# ./154516.h5
# tar: ./154516.h5: file changed as we read it
# ./154554.h5
# tar: ./154554.h5: file changed as we read it
# ./154597.h5
# tar: ./154597.h5: file changed as we read it
# ./154629.h5
# tar: ./154629.h5: file changed as we read it
# ./154657.h5
# tar: ./154657.h5: file changed as we read it
# ./154660.h5
# tar: ./154660.h5: file changed as we read it
# ./154691.h5
# tar: ./154691.h5: file changed as we read it
# ./154788.h5
# tar: ./154788.h5: file changed as we read it
# ./154987.h5
# tar: ./154987.h5: file changed as we read it
# ./155124.h5
# tar: ./155124.h5: file changed as we read it
# ./155157.h5
# tar: ./155157.h5: file changed as we read it
# ./155187.h5
# tar: ./155187.h5: file changed as we read it
# ./155193.h5
# tar: ./155193.h5: file changed as we read it
# ./155211.h5
# tar: ./155211.h5: file changed as we read it
# ./155217.h5
# tar: ./155217.h5: file changed as we read it
# ./155252.h5
# tar: ./155252.h5: file changed as we read it
# ./155442.h5
# tar: ./155442.h5: file changed as we read it
# ./155475.h5
# tar: ./155475.h5: file changed as we read it
# ./155524.h5
# tar: ./155524.h5: file changed as we read it
# ./155631.h5
# tar: ./155631.h5: file changed as we read it
# ./155643.h5
# tar: ./155643.h5: file changed as we read it
# ./155655.h5
# tar: ./155655.h5: file changed as we read it
# ./155697.h5
# tar: ./155697.h5: file changed as we read it
# ./155702.h5
# tar: ./155702.h5: file changed as we read it
# ./155704.h5
# tar: ./155704.h5: file changed as we read it
# ./155712.h5
# tar: ./155712.h5: file changed as we read it
# ./155753.h5
# tar: ./155753.h5: file changed as we read it
# ./155765.h5
# tar: ./155765.h5: file changed as we read it
# ./155803.h5
# tar: ./155803.h5: file changed as we read it
# ./155811.h5
# tar: ./155811.h5: file changed as we read it
# ./155869.h5
# tar: ./155869.h5: file changed as we read it
# ./155911.h5
# tar: ./155911.h5: file changed as we read it
# ./156031.h5
# tar: ./156031.h5: file changed as we read it
# ./156098.h5
# tar: ./156098.h5: file changed as we read it
# ./156123.h5
# tar: ./156123.h5: file changed as we read it
# ./156146.h5
# tar: ./156146.h5: file changed as we read it
# ./156150.h5
# tar: ./156150.h5: file changed as we read it
# ./156211.h5
# tar: ./156211.h5: file changed as we read it
# ./156281.h5
# tar: ./156281.h5: file changed as we read it
# ./156310.h5
# tar: ./156310.h5: file changed as we read it
# ./156312.h5
# tar: ./156312.h5: file changed as we read it
# ./156337.h5
# tar: ./156337.h5: file changed as we read it
# ./156401.h5
# tar: ./156401.h5: file changed as we read it
# ./156507.h5
# tar: ./156507.h5: file changed as we read it
# ./156533.h5
# tar: ./156533.h5: file changed as we read it
# ./156552.h5
# tar: ./156552.h5: file changed as we read it
# ./156559.h5
# tar: ./156559.h5: file changed as we read it
# ./156606.h5
# tar: ./156606.h5: file changed as we read it
# ./156698.h5
# tar: ./156698.h5: file changed as we read it
# ./156725.h5
# tar: ./156725.h5: file changed as we read it
# ./156803.h5
# tar: ./156803.h5: file changed as we read it
# ./156865.h5
# tar: ./156865.h5: file changed as we read it
# ./156913.h5
# tar: ./156913.h5: file changed as we read it
# ./156935.h5
# tar: ./156935.h5: file changed as we read it
# ./156940.h5
# tar: ./156940.h5: file changed as we read it
# ./156963.h5
# tar: ./156963.h5: file changed as we read it
# ./157003.h5
# tar: ./157003.h5: file changed as we read it
# ./157241.h5
# tar: ./157241.h5: file changed as we read it
# ./157245.h5
# tar: ./157245.h5: file changed as we read it
# ./157356.h5
# tar: ./157356.h5: file changed as we read it
# ./157404.h5
# tar: ./157404.h5: file changed as we read it
# ./157423.h5
# tar: ./157423.h5: file changed as we read it
# ./157448.h5
# tar: ./157448.h5: file changed as we read it
# ./157471.h5
# tar: ./157471.h5: file changed as we read it
# ./157508.h5
# tar: ./157508.h5: file changed as we read it
# ./157607.h5
# tar: ./157607.h5: file changed as we read it
# ./157659.h5
# tar: ./157659.h5: file changed as we read it
# ./157770.h5
# tar: ./157770.h5: file changed as we read it
# ./157797.h5
# tar: ./157797.h5: file changed as we read it
# ./157854.h5
# tar: ./157854.h5: file changed as we read it
# ./158026.h5
# tar: ./158026.h5: file changed as we read it
# ./158068.h5
# tar: ./158068.h5: file changed as we read it
# ./158142.h5
# tar: ./158142.h5: file changed as we read it
# ./158159.h5
# tar: ./158159.h5: file changed as we read it
# ./158201.h5
# tar: ./158201.h5: file changed as we read it
# ./158241.h5
# tar: ./158241.h5: file changed as we read it
# ./158275.h5
# tar: ./158275.h5: file changed as we read it
# ./158350.h5
# tar: ./158350.h5: file changed as we read it
# ./158392.h5
# tar: ./158392.h5: file changed as we read it
# ./158423.h5
# tar: ./158423.h5: file changed as we read it
# ./158460.h5
# tar: ./158460.h5: file changed as we read it
# ./158545.h5
# tar: ./158545.h5: file changed as we read it
# ./158550.h5
# tar: ./158550.h5: file changed as we read it
# ./158553.h5
# tar: ./158553.h5: file changed as we read it
# ./158617.h5
# tar: ./158617.h5: file changed as we read it
# ./158632.h5
# tar: ./158632.h5: file changed as we read it
# ./158728.h5
# tar: ./158728.h5: file changed as we read it
# ./158767.h5
# tar: ./158767.h5: file changed as we read it
# ./158817.h5
# tar: ./158817.h5: file changed as we read it
# ./158983.h5
# tar: ./158983.h5: file changed as we read it
# ./158998.h5
# tar: ./158998.h5: file changed as we read it
# ./159010.h5
# tar: ./159010.h5: file changed as we read it
# ./159055.h5
# tar: ./159055.h5: file changed as we read it
# ./159058.h5
# tar: ./159058.h5: file changed as we read it
# ./159102.h5
# tar: ./159102.h5: file changed as we read it
# ./159161.h5
# tar: ./159161.h5: file changed as we read it
# ./159181.h5
# tar: ./159181.h5: file changed as we read it
# ./159186.h5
# tar: ./159186.h5: file changed as we read it
# ./159240.h5
# tar: ./159240.h5: file changed as we read it
# ./159261.h5
# tar: ./159261.h5: file changed as we read it
# ./159283.h5
# tar: ./159283.h5: file changed as we read it
# ./159327.h5
# tar: ./159327.h5: file changed as we read it
# ./159368.h5
# tar: ./159368.h5: file changed as we read it
# ./159643.h5
# tar: ./159643.h5: file changed as we read it
# ./159774.h5
# tar: ./159774.h5: file changed as we read it
# ./159875.h5
# tar: ./159875.h5: file changed as we read it
# ./159879.h5
# tar: ./159879.h5: file changed as we read it
# ./159895.h5
# tar: ./159895.h5: file changed as we read it
# ./159961.h5
# tar: ./159961.h5: file changed as we read it
# ./159981.h5
# tar: ./159981.h5: file changed as we read it
# ./159997.h5
# tar: ./159997.h5: file changed as we read it
# ./160008.h5
# tar: ./160008.h5: file changed as we read it
# ./160011.h5
# tar: ./160011.h5: file changed as we read it
# ./160034.h5
# tar: ./160034.h5: file changed as we read it
# ./160081.h5
# tar: ./160081.h5: file changed as we read it
# ./160183.h5
# tar: ./160183.h5: file changed as we read it
# ./160235.h5
# tar: ./160235.h5: file changed as we read it
# ./160278.h5
# tar: ./160278.h5: file changed as we read it
# ./160351.h5
# tar: ./160351.h5: file changed as we read it
# ./160374.h5
# tar: ./160374.h5: file changed as we read it
# ./160416.h5
# tar: ./160416.h5: file changed as we read it
# ./160572.h5
# tar: ./160572.h5: file changed as we read it
# ./160689.h5
# tar: ./160689.h5: file changed as we read it
# ./160764.h5
# tar: ./160764.h5: file changed as we read it
# ./160806.h5
# tar: ./160806.h5: file changed as we read it
# ./160809.h5
# tar: ./160809.h5: file changed as we read it
# ./160881.h5
# tar: ./160881.h5: file changed as we read it
# ./160894.h5
# tar: ./160894.h5: file changed as we read it
# ./160967.h5
# tar: ./160967.h5: file changed as we read it
# ./161095.h5
# tar: ./161095.h5: file changed as we read it
# ./161103.h5
# tar: ./161103.h5: file changed as we read it
# ./161266.h5
# tar: ./161266.h5: file changed as we read it
# ./161328.h5
# tar: ./161328.h5: file changed as we read it
# ./161336.h5
# tar: ./161336.h5: file changed as we read it
# ./161467.h5
# tar: ./161467.h5: file changed as we read it
# ./161582.h5
# tar: ./161582.h5: file changed as we read it
# ./161586.h5
# tar: ./161586.h5: file changed as we read it
# ./161618.h5
# tar: ./161618.h5: file changed as we read it
# ./161704.h5
# tar: ./161704.h5: file changed as we read it
# ./161771.h5
# tar: ./161771.h5: file changed as we read it
# ./161774.h5
# tar: ./161774.h5: file changed as we read it
# ./161805.h5
# tar: ./161805.h5: file changed as we read it
# ./161866.h5
# tar: ./161866.h5: file changed as we read it
# ./161904.h5
# tar: ./161904.h5: file changed as we read it
# ./161911.h5
# tar: ./161911.h5: file changed as we read it
# ./161919.h5
# tar: ./161919.h5: file changed as we read it
# ./161995.h5
# tar: ./161995.h5: file changed as we read it
# ./162047.h5
# tar: ./162047.h5: file changed as we read it
# ./162109.h5
# tar: ./162109.h5: file changed as we read it
# ./162129.h5
# tar: ./162129.h5: file changed as we read it
# ./162138.h5
# tar: ./162138.h5: file changed as we read it
# ./162144.h5
# tar: ./162144.h5: file changed as we read it
# ./162428.h5
# tar: ./162428.h5: file changed as we read it
# ./162500.h5
# tar: ./162500.h5: file changed as we read it
# ./162516.h5
# tar: ./162516.h5: file changed as we read it
# ./162520.h5
# tar: ./162520.h5: file changed as we read it
# ./162525.h5
# tar: ./162525.h5: file changed as we read it
# ./162623.h5
# tar: ./162623.h5: file changed as we read it
# ./162632.h5
# tar: ./162632.h5: file changed as we read it
# ./162722.h5
# tar: ./162722.h5: file changed as we read it
# ./162756.h5
# tar: ./162756.h5: file changed as we read it
# ./162841.h5
# tar: ./162841.h5: file changed as we read it
# ./162954.h5
# tar: ./162954.h5: file changed as we read it
# ./163029.h5
# tar: ./163029.h5: file changed as we read it
# ./163051.h5
# tar: ./163051.h5: file changed as we read it
# ./163128.h5
# tar: ./163128.h5: file changed as we read it
# ./163154.h5
# ./163168.h5
# tar: ./163168.h5: file changed as we read it
# ./163266.h5
# tar: ./163266.h5: file changed as we read it
# ./163569.h5
# tar: ./163569.h5: file changed as we read it
# ./163599.h5
# tar: ./163599.h5: file changed as we read it
# ./163680.h5
# tar: ./163680.h5: file changed as we read it
# ./163711.h5
# tar: ./163711.h5: file changed as we read it
# ./163715.h5
# tar: ./163715.h5: file changed as we read it
# ./163719.h5
# tar: ./163719.h5: file changed as we read it
# ./163727.h5
# tar: ./163727.h5: file changed as we read it
# ./163776.h5
# tar: ./163776.h5: file changed as we read it
# ./163792.h5
# tar: ./163792.h5: file changed as we read it
# ./163809.h5
# tar: ./163809.h5: file changed as we read it
# ./163832.h5
# tar: ./163832.h5: file changed as we read it
# ./163999.h5
# tar: ./163999.h5: file changed as we read it
# ./164062.h5
# tar: ./164062.h5: file changed as we read it
# ./164250.h5
# tar: ./164250.h5: file changed as we read it
# ./164326.h5
# tar: ./164326.h5: file changed as we read it
# ./164353.h5
# tar: ./164353.h5: file changed as we read it
# ./164363.h5
# tar: ./164363.h5: file changed as we read it
# ./164364.h5
# tar: ./164364.h5: file changed as we read it
# ./164443.h5
# tar: ./164443.h5: file changed as we read it
# ./164570.h5
# tar: ./164570.h5: file changed as we read it
# ./164590.h5
# tar: ./164590.h5: file changed as we read it
# ./164663.h5
# tar: ./164663.h5: file changed as we read it
# ./164728.h5
# tar: ./164728.h5: file changed as we read it
# ./164780.h5
# tar: ./164780.h5: file changed as we read it
# ./164830.h5
# tar: ./164830.h5: file changed as we read it
# ./164847.h5
# tar: ./164847.h5: file changed as we read it
# ./164855.h5
# tar: ./164855.h5: file changed as we read it
# ./164887.h5
# tar: ./164887.h5: file changed as we read it
# ./164925.h5
# tar: ./164925.h5: file changed as we read it
# ./165009.h5
# tar: ./165009.h5: file changed as we read it
# ./165031.h5
# tar: ./165031.h5: file changed as we read it
# ./165038.h5
# tar: ./165038.h5: file changed as we read it
# ./165082.h5
# tar: ./165082.h5: file changed as we read it
# ./165101.h5
# tar: ./165101.h5: file changed as we read it
# ./165138.h5
# tar: ./165138.h5: file changed as we read it
# ./165157.h5
# tar: ./165157.h5: file changed as we read it
# ./165220.h5
# tar: ./165220.h5: file changed as we read it
# ./165341.h5
# tar: ./165341.h5: file changed as we read it
# ./165364.h5
# ./165599.h5
# tar: ./165599.h5: file changed as we read it
# ./165605.h5
# tar: ./165605.h5: file changed as we read it
# ./165668.h5
# tar: ./165668.h5: file changed as we read it
# ./165787.h5
# tar: ./165787.h5: file changed as we read it
# ./165922.h5
# tar: ./165922.h5: file changed as we read it
# ./166061.h5
# tar: ./166061.h5: file changed as we read it
# ./166102.h5
# tar: ./166102.h5: file changed as we read it
# ./166151.h5
# tar: ./166151.h5: file changed as we read it
# ./166219.h5
# tar: ./166219.h5: file changed as we read it
# ./166265.h5
# tar: ./166265.h5: file changed as we read it
# ./166324.h5
# tar: ./166324.h5: file changed as we read it
# ./166369.h5
# tar: ./166369.h5: file changed as we read it
# ./166373.h5
# tar: ./166373.h5: file changed as we read it
# ./166449.h5
# tar: ./166449.h5: file changed as we read it
# ./166608.h5
# tar: ./166608.h5: file changed as we read it
# ./166715.h5
# tar: ./166715.h5: file changed as we read it
# ./166776.h5
# tar: ./166776.h5: file changed as we read it
# ./166797.h5
# tar: ./166797.h5: file changed as we read it
# ./166815.h5
# tar: ./166815.h5: file changed as we read it
# ./166833.h5
# tar: ./166833.h5: file changed as we read it
# ./166892.h5
# tar: ./166892.h5: file changed as we read it
# ./166909.h5
# tar: ./166909.h5: file changed as we read it
# ./167033.h5
# tar: ./167033.h5: file changed as we read it
# ./167050.h5
# tar: ./167050.h5: file changed as we read it
# ./167149.h5
# tar: ./167149.h5: file changed as we read it
# ./167181.h5
# tar: ./167181.h5: file changed as we read it
# ./167242.h5
# tar: ./167242.h5: file changed as we read it
# ./167263.h5
# tar: ./167263.h5: file changed as we read it
# ./167397.h5
# tar: ./167397.h5: file changed as we read it
# ./167550.h5
# tar: ./167550.h5: file changed as we read it
# ./167575.h5
# tar: ./167575.h5: file changed as we read it
# ./167641.h5
# tar: ./167641.h5: file changed as we read it
# ./167829.h5
# tar: ./167829.h5: file changed as we read it
# ./167861.h5
# tar: ./167861.h5: file changed as we read it
# ./167884.h5
# tar: ./167884.h5: file changed as we read it
# ./167951.h5
# tar: ./167951.h5: file changed as we read it
# ./168001.h5
# tar: ./168001.h5: file changed as we read it
# ./168010.h5
# tar: ./168010.h5: file changed as we read it
# ./168026.h5
# tar: ./168026.h5: file changed as we read it
# ./168080.h5
# tar: ./168080.h5: file changed as we read it
# ./168089.h5
# tar: ./168089.h5: file changed as we read it
# ./168096.h5
# tar: ./168096.h5: file changed as we read it
# ./168114.h5
# tar: ./168114.h5: file changed as we read it
# ./168132.h5
# tar: ./168132.h5: file changed as we read it
# ./168156.h5
# tar: ./168156.h5: file changed as we read it
# ./168159.h5
# tar: ./168159.h5: file changed as we read it
# ./168298.h5
# tar: ./168298.h5: file changed as we read it
# ./168345.h5
# tar: ./168345.h5: file changed as we read it
# ./168563.h5
# tar: ./168563.h5: file changed as we read it
# ./168582.h5
# tar: ./168582.h5: file changed as we read it
# ./168651.h5
# tar: ./168651.h5: file changed as we read it
# ./168657.h5
# tar: ./168657.h5: file changed as we read it
# ./168666.h5
# tar: ./168666.h5: file changed as we read it
# ./168702.h5
# ./168704.h5
# tar: ./168704.h5: file changed as we read it
# ./168725.h5
# tar: ./168725.h5: file changed as we read it
# ./168763.h5
# tar: ./168763.h5: file changed as we read it
# ./168877.h5
# tar: ./168877.h5: file changed as we read it
# ./168900.h5
# tar: ./168900.h5: file changed as we read it
# ./168921.h5
# tar: ./168921.h5: file changed as we read it
# ./169057.h5
# tar: ./169057.h5: file changed as we read it
# ./169110.h5
# tar: ./169110.h5: file changed as we read it
# ./169140.h5
# tar: ./169140.h5: file changed as we read it
# ./169165.h5
# tar: ./169165.h5: file changed as we read it
# ./169214.h5
# tar: ./169214.h5: file changed as we read it
# ./169334.h5
# tar: ./169334.h5: file changed as we read it
# ./169383.h5
# tar: ./169383.h5: file changed as we read it
# ./169400.h5
# tar: ./169400.h5: file changed as we read it
# ./169476.h5
# tar: ./169476.h5: file changed as we read it
# ./169506.h5
# tar: ./169506.h5: file changed as we read it
# ./169526.h5
# tar: ./169526.h5: file changed as we read it
# ./169552.h5
# tar: ./169552.h5: file changed as we read it
# ./169575.h5
# tar: ./169575.h5: file changed as we read it
# ./169635.h5
# tar: ./169635.h5: file changed as we read it
# ./169670.h5
# tar: ./169670.h5: file changed as we read it
# ./169720.h5
# tar: ./169720.h5: file changed as we read it
# ./169800.h5
# tar: ./169800.h5: file changed as we read it
# ./170070.h5
# tar: ./170070.h5: file changed as we read it
# ./170075.h5
# tar: ./170075.h5: file changed as we read it
# ./170079.h5
# tar: ./170079.h5: file changed as we read it
# ./170084.h5
# tar: ./170084.h5: file changed as we read it
# ./170086.h5
# tar: ./170086.h5: file changed as we read it
# ./170160.h5
# tar: ./170160.h5: file changed as we read it
# ./170245.h5
# tar: ./170245.h5: file changed as we read it
# ./170277.h5
# tar: ./170277.h5: file changed as we read it
# ./170293.h5
# tar: ./170293.h5: file changed as we read it
# ./170399.h5
# tar: ./170399.h5: file changed as we read it
# ./170417.h5
# tar: ./170417.h5: file changed as we read it
# ./170471.h5
# tar: ./170471.h5: file changed as we read it
# ./170475.h5
# tar: ./170475.h5: file changed as we read it
# ./170496.h5
# tar: ./170496.h5: file changed as we read it
# ./170549.h5
# tar: ./170549.h5: file changed as we read it
# ./170656.h5
# tar: ./170656.h5: file changed as we read it
# ./170771.h5
# tar: ./170771.h5: file changed as we read it
# ./170801.h5
# tar: ./170801.h5: file changed as we read it
# ./170841.h5
# tar: ./170841.h5: file changed as we read it
# ./170897.h5
# tar: ./170897.h5: file changed as we read it
# ./170962.h5
# tar: ./170962.h5: file changed as we read it
# ./171026.h5
# tar: ./171026.h5: file changed as we read it
# ./171095.h5
# tar: ./171095.h5: file changed as we read it
# ./171137.h5
# tar: ./171137.h5: file changed as we read it
# ./171264.h5
# tar: ./171264.h5: file changed as we read it
# ./171283.h5
# tar: ./171283.h5: file changed as we read it
# ./171284.h5
# tar: ./171284.h5: file changed as we read it
# ./171360.h5
# tar: ./171360.h5: file changed as we read it
# ./171587.h5
# tar: ./171587.h5: file changed as we read it
# ./171691.h5
# tar: ./171691.h5: file changed as we read it
# ./171746.h5
# tar: ./171746.h5: file changed as we read it
# ./171777.h5
# tar: ./171777.h5: file changed as we read it
# ./171802.h5
# tar: ./171802.h5: file changed as we read it
# ./171841.h5
# tar: ./171841.h5: file changed as we read it
# ./171940.h5
# tar: ./171940.h5: file changed as we read it
# ./171968.h5
# tar: ./171968.h5: file changed as we read it
# ./172045.h5
# tar: ./172045.h5: file changed as we read it
# ./172123.h5
# tar: ./172123.h5: file changed as we read it
# ./172141.h5
# tar: ./172141.h5: file changed as we read it
# ./172157.h5
# tar: ./172157.h5: file changed as we read it
# ./172228.h5
# tar: ./172228.h5: file changed as we read it
# ./172236.h5
# tar: ./172236.h5: file changed as we read it
# ./172306.h5
# tar: ./172306.h5: file changed as we read it
# ./172312.h5
# tar: ./172312.h5: file changed as we read it
# ./172395.h5
# tar: ./172395.h5: file changed as we read it
# ./172425.h5
# tar: ./172425.h5: file changed as we read it
# ./172426.h5
# tar: ./172426.h5: file changed as we read it
# ./172482.h5
# tar: ./172482.h5: file changed as we read it
# ./172634.h5
# tar: ./172634.h5: file changed as we read it
# ./172635.h5
# tar: ./172635.h5: file changed as we read it
# ./172724.h5
# tar: ./172724.h5: file changed as we read it
# ./172789.h5
# tar: ./172789.h5: file changed as we read it
# ./172822.h5
# tar: ./172822.h5: file changed as we read it
# ./173020.h5
# tar: ./173020.h5: file changed as we read it
# ./173037.h5
# tar: ./173037.h5: file changed as we read it
# ./173046.h5
# tar: ./173046.h5: file changed as we read it
# ./173334.h5
# tar: ./173334.h5: file changed as we read it
# ./173505.h5
# tar: ./173505.h5: file changed as we read it
# ./173513.h5
# tar: ./173513.h5: file changed as we read it
# ./173560.h5
# tar: ./173560.h5: file changed as we read it
# ./173623.h5
# tar: ./173623.h5: file changed as we read it
# ./173641.h5
# tar: ./173641.h5: file changed as we read it
# ./173774.h5
# tar: ./173774.h5: file changed as we read it
# ./173831.h5
# tar: ./173831.h5: file changed as we read it
# ./173956.h5
# tar: ./173956.h5: file changed as we read it
# ./174064.h5
# tar: ./174064.h5: file changed as we read it
# ./174292.h5
# tar: ./174292.h5: file changed as we read it
# ./174422.h5
# tar: ./174422.h5: file changed as we read it
# ./174457.h5
# tar: ./174457.h5: file changed as we read it
# ./174463.h5
# tar: ./174463.h5: file changed as we read it
# ./174474.h5
# tar: ./174474.h5: file changed as we read it
# ./174493.h5
# tar: ./174493.h5: file changed as we read it
# ./174537.h5
# tar: ./174537.h5: file changed as we read it
# ./174637.h5
# tar: ./174637.h5: file changed as we read it
# ./174683.h5
# tar: ./174683.h5: file changed as we read it
# ./174687.h5
# tar: ./174687.h5: file changed as we read it
# ./174926.h5
# tar: ./174926.h5: file changed as we read it
# ./174958.h5
# tar: ./174958.h5: file changed as we read it
# ./175007.h5
# tar: ./175007.h5: file changed as we read it
# ./175028.h5
# tar: ./175028.h5: file changed as we read it
# ./175049.h5
# tar: ./175049.h5: file changed as we read it
# ./175193.h5
# tar: ./175193.h5: file changed as we read it
# ./175195.h5
# tar: ./175195.h5: file changed as we read it
# ./175324.h5
# tar: ./175324.h5: file changed as we read it
# ./175403.h5
# tar: ./175403.h5: file changed as we read it
# ./175407.h5
# tar: ./175407.h5: file changed as we read it
# ./175634.h5
# tar: ./175634.h5: file changed as we read it
# ./175898.h5
# tar: ./175898.h5: file changed as we read it
# ./176002.h5
# tar: ./176002.h5: file changed as we read it
# ./176031.h5
# tar: ./176031.h5: file changed as we read it
# ./176075.h5
# tar: ./176075.h5: file changed as we read it
# ./176078.h5
# tar: ./176078.h5: file changed as we read it
# ./176113.h5
# tar: ./176113.h5: file changed as we read it
# ./176160.h5
# tar: ./176160.h5: file changed as we read it
# ./176245.h5
# tar: ./176245.h5: file changed as we read it
# ./176249.h5
# tar: ./176249.h5: file changed as we read it
# ./176277.h5
# tar: ./176277.h5: file changed as we read it
# ./176291.h5
# tar: ./176291.h5: file changed as we read it
# ./176399.h5
# tar: ./176399.h5: file changed as we read it
# ./176401.h5
# tar: ./176401.h5: file changed as we read it
# ./176451.h5
# tar: ./176451.h5: file changed as we read it
# ./176455.h5
# tar: ./176455.h5: file changed as we read it
# ./176467.h5
# tar: ./176467.h5: file changed as we read it
# ./176542.h5
# tar: ./176542.h5: file changed as we read it
# ./176600.h5
# tar: ./176600.h5: file changed as we read it
# ./176645.h5
# tar: ./176645.h5: file changed as we read it
# ./176648.h5
# tar: ./176648.h5: file changed as we read it
# ./176683.h5
# tar: ./176683.h5: file changed as we read it
# ./176688.h5
# tar: ./176688.h5: file changed as we read it
# ./176694.h5
# tar: ./176694.h5: file changed as we read it
# ./176722.h5
# tar: ./176722.h5: file changed as we read it
# ./176731.h5
# tar: ./176731.h5: file changed as we read it
# ./176814.h5
# tar: ./176814.h5: file changed as we read it
# ./176875.h5
# tar: ./176875.h5: file changed as we read it
# ./176927.h5
# tar: ./176927.h5: file changed as we read it
# ./176996.h5
# tar: ./176996.h5: file changed as we read it
# ./177080.h5
# tar: ./177080.h5: file changed as we read it
# ./177180.h5
# tar: ./177180.h5: file changed as we read it
# ./177210.h5
# tar: ./177210.h5: file changed as we read it
# ./177228.h5
# tar: ./177228.h5: file changed as we read it
# ./177237.h5
# tar: ./177237.h5: file changed as we read it
# ./177252.h5
# ./177366.h5
# tar: ./177366.h5: file changed as we read it
# ./177419.h5
# tar: ./177419.h5: file changed as we read it
# ./177466.h5
# tar: ./177466.h5: file changed as we read it
# ./177531.h5
# tar: ./177531.h5: file changed as we read it
# ./177535.h5
# tar: ./177535.h5: file changed as we read it
# ./177601.h5
# tar: ./177601.h5: file changed as we read it
# ./177658.h5
# tar: ./177658.h5: file changed as we read it
# ./177660.h5
# tar: ./177660.h5: file changed as we read it
# ./177741.h5
# tar: ./177741.h5: file changed as we read it
# ./177755.h5
# tar: ./177755.h5: file changed as we read it
# ./177887.h5
# tar: ./177887.h5: file changed as we read it
# ./177900.h5
# tar: ./177900.h5: file changed as we read it
# ./177992.h5
# tar: ./177992.h5: file changed as we read it
# ./178032.h5
# tar: ./178032.h5: file changed as we read it
# ./178042.h5
# tar: ./178042.h5: file changed as we read it
# ./178082.h5
# tar: ./178082.h5: file changed as we read it
# ./178160.h5
# tar: ./178160.h5: file changed as we read it
# ./178257.h5
# tar: ./178257.h5: file changed as we read it
# ./178295.h5
# tar: ./178295.h5: file changed as we read it
# ./178329.h5
# tar: ./178329.h5: file changed as we read it
# ./178360.h5
# tar: ./178360.h5: file changed as we read it
# ./178418.h5
# tar: ./178418.h5: file changed as we read it
# ./178444.h5
# tar: ./178444.h5: file changed as we read it
# ./178519.h5
# tar: ./178519.h5: file changed as we read it
# ./178580.h5
# tar: ./178580.h5: file changed as we read it
# ./178686.h5
# tar: ./178686.h5: file changed as we read it
# ./178719.h5
# tar: ./178719.h5: file changed as we read it
# ./178774.h5
# tar: ./178774.h5: file changed as we read it
# ./178808.h5
# tar: ./178808.h5: file changed as we read it
# ./178876.h5
# tar: ./178876.h5: file changed as we read it
# ./178989.h5
# tar: ./178989.h5: file changed as we read it
# ./179000.h5
# tar: ./179000.h5: file changed as we read it
# ./179009.h5
# tar: ./179009.h5: file changed as we read it
# ./179049.h5
# tar: ./179049.h5: file changed as we read it
# ./179149.h5
# tar: ./179149.h5: file changed as we read it
# ./179156.h5
# tar: ./179156.h5: file changed as we read it
# ./179164.h5
# tar: ./179164.h5: file changed as we read it
# ./179220.h5
# tar: ./179220.h5: file changed as we read it
# ./179252.h5
# tar: ./179252.h5: file changed as we read it
# ./179284.h5
# tar: ./179284.h5: file changed as we read it
# ./179355.h5
# tar: ./179355.h5: file changed as we read it
# ./179480.h5
# tar: ./179480.h5: file changed as we read it
# ./179511.h5
# tar: ./179511.h5: file changed as we read it
# ./179526.h5
# tar: ./179526.h5: file changed as we read it
# ./179577.h5
# tar: ./179577.h5: file changed as we read it
# ./179635.h5
# tar: ./179635.h5: file changed as we read it
# ./179680.h5
# tar: ./179680.h5: file changed as we read it
# ./179723.h5
# tar: ./179723.h5: file changed as we read it
# ./179742.h5
# tar: ./179742.h5: file changed as we read it
# ./179872.h5
# tar: ./179872.h5: file changed as we read it
# ./179875.h5
# tar: ./179875.h5: file changed as we read it
# ./179891.h5
# tar: ./179891.h5: file changed as we read it
# ./179900.h5
# tar: ./179900.h5: file changed as we read it
# ./179908.h5
# tar: ./179908.h5: file changed as we read it
# ./179930.h5
# tar: ./179930.h5: file changed as we read it
# ./180016.h5
# tar: ./180016.h5: file changed as we read it
# ./180017.h5
# tar: ./180017.h5: file changed as we read it
# ./180137.h5
# tar: ./180137.h5: file changed as we read it
# ./180549.h5
# tar: ./180549.h5: file changed as we read it
# ./180568.h5
# tar: ./180568.h5: file changed as we read it
# ./180587.h5
# tar: ./180587.h5: file changed as we read it
# ./180633.h5
# tar: ./180633.h5: file changed as we read it
# ./180810.h5
# tar: ./180810.h5: file changed as we read it
# ./180816.h5
# tar: ./180816.h5: file changed as we read it
# ./180882.h5
# tar: ./180882.h5: file changed as we read it
# ./180950.h5
# tar: ./180950.h5: file changed as we read it
# ./181019.h5
# tar: ./181019.h5: file changed as we read it
# ./181103.h5
# tar: ./181103.h5: file changed as we read it
# ./181119.h5
# tar: ./181119.h5: file changed as we read it
# ./181137.h5
# tar: ./181137.h5: file changed as we read it
# ./181162.h5
# tar: ./181162.h5: file changed as we read it
# ./181222.h5
# tar: ./181222.h5: file changed as we read it
# ./181247.h5
# tar: ./181247.h5: file changed as we read it
# ./181384.h5
# tar: ./181384.h5: file changed as we read it
# ./181397.h5
# tar: ./181397.h5: file changed as we read it
# ./181580.h5
# tar: ./181580.h5: file changed as we read it
# ./181614.h5
# tar: ./181614.h5: file changed as we read it
# ./181649.h5
# tar: ./181649.h5: file changed as we read it
# ./181711.h5
# tar: ./181711.h5: file changed as we read it
# ./181772.h5
# tar: ./181772.h5: file changed as we read it
# ./181836.h5
# tar: ./181836.h5: file changed as we read it
# ./181938.h5
# tar: ./181938.h5: file changed as we read it
# ./181980.h5
# tar: ./181980.h5: file changed as we read it
# ./182010.h5
# tar: ./182010.h5: file changed as we read it
# ./182040.h5
# tar: ./182040.h5: file changed as we read it
# ./182065.h5
# tar: ./182065.h5: file changed as we read it
# ./182072.h5
# tar: ./182072.h5: file changed as we read it
# ./182155.h5
# tar: ./182155.h5: file changed as we read it
# ./182164.h5
# tar: ./182164.h5: file changed as we read it
# ./182210.h5
# tar: ./182210.h5: file changed as we read it
# ./182300.h5
# tar: ./182300.h5: file changed as we read it
# ./182305.h5
# tar: ./182305.h5: file changed as we read it
# ./182474.h5
# tar: ./182474.h5: file changed as we read it
# ./182475.h5
# tar: ./182475.h5: file changed as we read it
# ./183395.h5
# tar: ./183395.h5: file changed as we read it
# ./183481.h5
# tar: ./183481.h5: file changed as we read it
# ./183500.h5
# tar: ./183500.h5: file changed as we read it
# ./183521.h5
# tar: ./183521.h5: file changed as we read it
# ./183523.h5
# tar: ./183523.h5: file changed as we read it
# ./183557.h5
# tar: ./183557.h5: file changed as we read it
# ./183680.h5
# tar: ./183680.h5: file changed as we read it
# ./183697.h5
# tar: ./183697.h5: file changed as we read it
# ./183700.h5
# tar: ./183700.h5: file changed as we read it
# ./183712.h5
# tar: ./183712.h5: file changed as we read it
# ./183744.h5
# tar: ./183744.h5: file changed as we read it
# ./183780.h5
# tar: ./183780.h5: file changed as we read it
# ./183797.h5
# tar: ./183797.h5: file changed as we read it
# ./183825.h5
# tar: ./183825.h5: file changed as we read it
# ./183838.h5
# tar: ./183838.h5: file changed as we read it
# ./183899.h5
# tar: ./183899.h5: file changed as we read it
# ./183944.h5
# tar: ./183944.h5: file changed as we read it
# ./183995.h5
# tar: ./183995.h5: file changed as we read it
# ./184067.h5
# tar: ./184067.h5: file changed as we read it
# ./184087.h5
# tar: ./184087.h5: file changed as we read it
# ./184117.h5
# tar: ./184117.h5: file changed as we read it
# ./184156.h5
# tar: ./184156.h5: file changed as we read it
# ./184210.h5
# tar: ./184210.h5: file changed as we read it
# ./184240.h5
# tar: ./184240.h5: file changed as we read it
# ./184301.h5
# tar: ./184301.h5: file changed as we read it
# ./184370.h5
# tar: ./184370.h5: file changed as we read it
# ./184385.h5
# tar: ./184385.h5: file changed as we read it
# ./184433.h5
# tar: ./184433.h5: file changed as we read it
# ./184457.h5
# tar: ./184457.h5: file changed as we read it
# ./184811.h5
# tar: ./184811.h5: file changed as we read it
# ./184817.h5
# tar: ./184817.h5: file changed as we read it
# ./184839.h5
# tar: ./184839.h5: file changed as we read it
# ./184851.h5
# tar: ./184851.h5: file changed as we read it
# ./184893.h5
# tar: ./184893.h5: file changed as we read it
# ./184910.h5
# tar: ./184910.h5: file changed as we read it
# ./184959.h5
# tar: ./184959.h5: file changed as we read it
# ./185018.h5
# tar: ./185018.h5: file changed as we read it
# ./185072.h5
# tar: ./185072.h5: file changed as we read it
# ./185195.h5
# tar: ./185195.h5: file changed as we read it
# ./185414.h5
# tar: ./185414.h5: file changed as we read it
# ./185446.h5
# tar: ./185446.h5: file changed as we read it
# ./185611.h5
# tar: ./185611.h5: file changed as we read it
# ./185630.h5
# tar: ./185630.h5: file changed as we read it
# ./185650.h5
# tar: ./185650.h5: file changed as we read it
# ./185651.h5
# tar: ./185651.h5: file changed as we read it
# ./185757.h5
# tar: ./185757.h5: file changed as we read it
# ./185791.h5
# tar: ./185791.h5: file changed as we read it
# ./185907.h5
# tar: ./185907.h5: file changed as we read it
# ./185946.h5
# tar: ./185946.h5: file changed as we read it
# ./186010.h5
# tar: ./186010.h5: file changed as we read it
# ./186074.h5
# tar: ./186074.h5: file changed as we read it
# ./186125.h5
# tar: ./186125.h5: file changed as we read it
# ./186158.h5
# tar: ./186158.h5: file changed as we read it
# ./186206.h5
# tar: ./186206.h5: file changed as we read it
# ./186288.h5
# tar: ./186288.h5: file changed as we read it
# ./186345.h5
# tar: ./186345.h5: file changed as we read it
# ./186405.h5
# tar: ./186405.h5: file changed as we read it
# ./186437.h5
# tar: ./186437.h5: file changed as we read it
# ./186459.h5
# tar: ./186459.h5: file changed as we read it
# ./186511.h5
# tar: ./186511.h5: file changed as we read it
# ./186546.h5
# tar: ./186546.h5: file changed as we read it
# ./186549.h5
# tar: ./186549.h5: file changed as we read it
# ./186556.h5
# tar: ./186556.h5: file changed as we read it
# ./186683.h5
# tar: ./186683.h5: file changed as we read it
# ./186728.h5
# tar: ./186728.h5: file changed as we read it
# ./186787.h5
# tar: ./186787.h5: file changed as we read it
# ./186804.h5
# tar: ./186804.h5: file changed as we read it
# ./186955.h5
# tar: ./186955.h5: file changed as we read it
# ./187029.h5
# tar: ./187029.h5: file changed as we read it
# ./187103.h5
# tar: ./187103.h5: file changed as we read it
# ./187151.h5
# tar: ./187151.h5: file changed as we read it
# ./187230.h5
# tar: ./187230.h5: file changed as we read it
# ./187310.h5
# tar: ./187310.h5: file changed as we read it
# ./187311.h5
# tar: ./187311.h5: file changed as we read it
# ./187352.h5
# tar: ./187352.h5: file changed as we read it
# ./187362.h5
# tar: ./187362.h5: file changed as we read it
# ./187403.h5
# tar: ./187403.h5: file changed as we read it
# ./187409.h5
# tar: ./187409.h5: file changed as we read it
# ./187495.h5
# tar: ./187495.h5: file changed as we read it
# ./187510.h5
# tar: ./187510.h5: file changed as we read it
# ./187632.h5
# tar: ./187632.h5: file changed as we read it
# ./187748.h5
# tar: ./187748.h5: file changed as we read it
# ./187789.h5
# tar: ./187789.h5: file changed as we read it
# ./187833.h5
# tar: ./187833.h5: file changed as we read it
# ./187891.h5
# tar: ./187891.h5: file changed as we read it
# ./187905.h5
# tar: ./187905.h5: file changed as we read it
# ./187965.h5
# tar: ./187965.h5: file changed as we read it
# ./188028.h5
# tar: ./188028.h5: file changed as we read it
# ./188048.h5
# tar: ./188048.h5: file changed as we read it
# ./188101.h5
# tar: ./188101.h5: file changed as we read it
# ./188127.h5
# tar: ./188127.h5: file changed as we read it
# ./188283.h5
# tar: ./188283.h5: file changed as we read it
# ./188289.h5
# tar: ./188289.h5: file changed as we read it
# ./188478.h5
# tar: ./188478.h5: file changed as we read it
# ./188494.h5
# tar: ./188494.h5: file changed as we read it
# ./188502.h5
# tar: ./188502.h5: file changed as we read it
# ./188538.h5
# tar: ./188538.h5: file changed as we read it
# ./188549.h5
# tar: ./188549.h5: file changed as we read it
# ./188655.h5
# tar: ./188655.h5: file changed as we read it
# ./188702.h5
# tar: ./188702.h5: file changed as we read it
# ./188828.h5
# tar: ./188828.h5: file changed as we read it
# ./188835.h5
# tar: ./188835.h5: file changed as we read it
# ./188983.h5
# tar: ./188983.h5: file changed as we read it
# ./188990.h5
# tar: ./188990.h5: file changed as we read it
# ./189021.h5
# tar: ./189021.h5: file changed as we read it
# ./189138.h5
# tar: ./189138.h5: file changed as we read it
# ./189178.h5
# tar: ./189178.h5: file changed as we read it
# ./189184.h5
# tar: ./189184.h5: file changed as we read it
# ./189258.h5
# tar: ./189258.h5: file changed as we read it
# ./189271.h5
# tar: ./189271.h5: file changed as we read it
# ./189429.h5
# tar: ./189429.h5: file changed as we read it
# ./189661.h5
# tar: ./189661.h5: file changed as we read it
# ./189788.h5
# tar: ./189788.h5: file changed as we read it
# ./189964.h5
# tar: ./189964.h5: file changed as we read it
# ./189986.h5
# tar: ./189986.h5: file changed as we read it
# ./190123.h5
# tar: ./190123.h5: file changed as we read it
# ./190150.h5
# tar: ./190150.h5: file changed as we read it
# ./190419.h5
# tar: ./190419.h5: file changed as we read it
# ./190595.h5
# tar: ./190595.h5: file changed as we read it
# ./190601.h5
# tar: ./190601.h5: file changed as we read it
# ./190749.h5
# tar: ./190749.h5: file changed as we read it
# ./190756.h5
# tar: ./190756.h5: file changed as we read it
# ./190762.h5
# tar: ./190762.h5: file changed as we read it
# ./190788.h5
# tar: ./190788.h5: file changed as we read it
# ./190792.h5
# tar: ./190792.h5: file changed as we read it
# ...
# ./273323.h5
# tar: ./273323.h5: file changed as we read it
# ./273331.h5
# tar: ./273331.h5: file changed as we read it
# ./262719.h5
# tar: ./262719.h5: file changed as we read it
# ./268424.h5
# tar: ./268424.h5: file changed as we read it
# ./273400.h5
# tar: ./273400.h5: file changed as we read it
# ./268441.h5
# tar: ./268441.h5: file changed as we read it
# ./273437.h5
# tar: ./273437.h5: file changed as we read it
# ./262805.h5
# tar: ./262805.h5: file changed as we read it
# ./273490.h5
# tar: ./273490.h5: file changed as we read it
# ./262911.h5
# tar: ./262911.h5: file changed as we read it
# ./268605.h5
# tar: ./268605.h5: file changed as we read it
# ./273582.h5
# tar: ./273582.h5: file changed as we read it
# ./273586.h5
# tar: ./273586.h5: file changed as we read it
# ./273612.h5
# tar: ./273612.h5: file changed as we read it
# ./273620.h5
# tar: ./273620.h5: file changed as we read it
# ./262973.h5
# tar: ./262973.h5: file changed as we read it
# ./273661.h5
# tar: ./273661.h5: file changed as we read it
# ./268692.h5
# tar: ./268692.h5: file changed as we read it
# ./263026.h5
# tar: ./263026.h5: file changed as we read it
# ./268741.h5
# tar: ./268741.h5: file changed as we read it
# ./268771.h5
# tar: ./268771.h5: file changed as we read it
# ./263121.h5
# tar: ./263121.h5: file changed as we read it
# ./268874.h5
# tar: ./268874.h5: file changed as we read it
# ./263179.h5
# tar: ./263179.h5: file changed as we read it
# ./263185.h5
# tar: ./263185.h5: file changed as we read it
# ./263209.h5
# tar: ./263209.h5: file changed as we read it
# ./263212.h5
# tar: ./263212.h5: file changed as we read it
# ./263254.h5
# tar: ./263254.h5: file changed as we read it
# ./263265.h5
# tar: ./263265.h5: file changed as we read it
# ./263281.h5
# tar: ./263281.h5: file changed as we read it
# ./263295.h5
# tar: ./263295.h5: file changed as we read it
# ./263306.h5
# tar: ./263306.h5: file changed as we read it
# ./269125.h5
# tar: ./269125.h5: file changed as we read it
# ./263466.h5
# tar: ./263466.h5: file changed as we read it
# ./269187.h5
# tar: ./269187.h5: file changed as we read it
# ./263492.h5
# tar: ./263492.h5: file changed as we read it
# ./269230.h5
# tar: ./269230.h5: file changed as we read it
# ./269251.h5
# tar: ./269251.h5: file changed as we read it
# ./269265.h5
# tar: ./269265.h5: file changed as we read it
# ./263564.h5
# tar: ./263564.h5: file changed as we read it
# ./263589.h5
# tar: ./263589.h5: file changed as we read it
# ./269304.h5
# tar: ./269304.h5: file changed as we read it
# ./263645.h5
# tar: ./263645.h5: file changed as we read it
# ./263656.h5
# tar: ./263656.h5: file changed as we read it
# ./263662.h5
# tar: ./263662.h5: file changed as we read it
# ./263666.h5
# tar: ./263666.h5: file changed as we read it
# ./269439.h5
# tar: ./269439.h5: file changed as we read it
# ./263750.h5
# tar: ./263750.h5: file changed as we read it
# ./269476.h5
# tar: ./269476.h5: file changed as we read it
# ./269561.h5
# tar: ./269561.h5: file changed as we read it
# ./263865.h5
# tar: ./263865.h5: file changed as we read it
# ./263894.h5
# tar: ./263894.h5: file changed as we read it
# ./269618.h5
# tar: ./269618.h5: file changed as we read it
# ./269714.h5
# tar: ./269714.h5: file changed as we read it
# ./264033.h5
# tar: ./264033.h5: file changed as we read it
# ./269810.h5
# tar: ./269810.h5: file changed as we read it
# ./269828.h5
# tar: ./269828.h5: file changed as we read it
# ./264120.h5
# tar: ./264120.h5: file changed as we read it
# ./264128.h5
# tar: ./264128.h5: file changed as we read it
# ./264134.h5
# tar: ./264134.h5: file changed as we read it
# ./269844.h5
# tar: ./269844.h5: file changed as we read it
# ./264161.h5
# tar: ./264161.h5: file changed as we read it
# ./264164.h5
# tar: ./264164.h5: file changed as we read it
# ./264211.h5
# tar: ./264211.h5: file changed as we read it
# ./269935.h5
# tar: ./269935.h5: file changed as we read it
# ./269982.h5
# tar: ./269982.h5: file changed as we read it
# ./264369.h5
# tar: ./264369.h5: file changed as we read it
# ./264390.h5
# tar: ./264390.h5: file changed as we read it
# ./264460.h5
# tar: ./264460.h5: file changed as we read it
# ./264470.h5
# tar: ./264470.h5: file changed as we read it
# ./264552.h5
# tar: ./264552.h5: file changed as we read it
# ./264582.h5
# tar: ./264582.h5: file changed as we read it
# ./264605.h5
# tar: ./264605.h5: file changed as we read it
# ./264630.h5
# tar: ./264630.h5: file changed as we read it
# ./264642.h5
# tar: ./264642.h5: file changed as we read it
# ./264806.h5
# tar: ./264806.h5: file changed as we read it
# ./264807.h5
# tar: ./264807.h5: file changed as we read it
# ./264890.h5
# tar: ./264890.h5: file changed as we read it
# ./264907.h5
# ./264933.h5
# tar: ./264933.h5: file changed as we read it
# ./273867.h5
# tar: ./273867.h5: file changed as we read it
# ./273891.h5
# tar: ./273891.h5: file changed as we read it
# ./273982.h5
# tar: ./273982.h5: file changed as we read it
# ./274055.h5
# tar: ./274055.h5: file changed as we read it
# ./274369.h5
# tar: ./274369.h5: file changed as we read it
# ./274385.h5
# tar: ./274385.h5: file changed as we read it
# ./274417.h5
# tar: ./274417.h5: file changed as we read it
# ./274419.h5
# tar: ./274419.h5: file changed as we read it
# ./274472.h5
# tar: ./274472.h5: file changed as we read it
# ./274598.h5
# tar: ./274598.h5: file changed as we read it
# ./274671.h5
# tar: ./274671.h5: file changed as we read it
# ./274880.h5
# tar: ./274880.h5: file changed as we read it
# ./274883.h5
# tar: ./274883.h5: file changed as we read it
# ./274899.h5
# tar: ./274899.h5: file changed as we read it
# ./275058.h5
# tar: ./275058.h5: file changed as we read it
# ./275060.h5
# tar: ./275060.h5: file changed as we read it
# ./275082.h5
# tar: ./275082.h5: file changed as we read it
# ./275365.h5
# tar: ./275365.h5: file changed as we read it
# ./275471.h5
# tar: ./275471.h5: file changed as we read it
# ./275529.h5
# tar: ./275529.h5: file changed as we read it
# ./275544.h5
# tar: ./275544.h5: file changed as we read it
# ./275709.h5
# tar: ./275709.h5: file changed as we read it
# ./275758.h5
# tar: ./275758.h5: file changed as we read it
# ./275878.h5
# tar: ./275878.h5: file changed as we read it
# ./275891.h5
# tar: ./275891.h5: file changed as we read it
# ./276112.h5
# tar: ./276112.h5: file changed as we read it
# ./276148.h5
# tar: ./276148.h5: file changed as we read it
# ./276309.h5
# tar: ./276309.h5: file changed as we read it
# ./276384.h5
# tar: ./276384.h5: file changed as we read it
# ./276467.h5
# tar: ./276467.h5: file changed as we read it
# ./276641.h5
# tar: ./276641.h5: file changed as we read it
# ./276659.h5
# tar: ./276659.h5: file changed as we read it
# ./276671.h5
# tar: ./276671.h5: file changed as we read it
# ./276746.h5
# tar: ./276746.h5: file changed as we read it
# ./276765.h5
# ./276792.h5
# tar: ./276792.h5: file changed as we read it
# ./276853.h5
# tar: ./276853.h5: file changed as we read it
# ./276886.h5
# ./277115.h5
# tar: ./277115.h5: file changed as we read it
# ./277138.h5
# tar: ./277138.h5: file changed as we read it
# ./277159.h5
# tar: ./277159.h5: file changed as we read it
# ./277263.h5
# tar: ./277263.h5: file changed as we read it
# ./277477.h5
# tar: ./277477.h5: file changed as we read it
# ./277520.h5
# tar: ./277520.h5: file changed as we read it
# ./277595.h5
# tar: ./277595.h5: file changed as we read it
# ./277634.h5
# tar: ./277634.h5: file changed as we read it
# ./277685.h5
# tar: ./277685.h5: file changed as we read it
# ./277756.h5
# tar: ./277756.h5: file changed as we read it
# ./277830.h5
# tar: ./277830.h5: file changed as we read it
# ./277844.h5
# tar: ./277844.h5: file changed as we read it
# ./277995.h5
# tar: ./277995.h5: file changed as we read it
# ./278245.h5
# tar: ./278245.h5: file changed as we read it
# ./278318.h5
# tar: ./278318.h5: file changed as we read it
# ./278409.h5
# tar: ./278409.h5: file changed as we read it
# ./278471.h5
# tar: ./278471.h5: file changed as we read it
# ./278557.h5
# tar: ./278557.h5: file changed as we read it
# ./278565.h5
# tar: ./278565.h5: file changed as we read it
# ./278777.h5
# tar: ./278777.h5: file changed as we read it
# ./278879.h5
# tar: ./278879.h5: file changed as we read it
# ./278905.h5
# tar: ./278905.h5: file changed as we read it
# ./278937.h5
# tar: ./278937.h5: file changed as we read it
# ./279100.h5
# tar: ./279100.h5: file changed as we read it
# ./279511.h5
# tar: ./279511.h5: file changed as we read it
# ./279513.h5
# tar: ./279513.h5: file changed as we read it
# ./279639.h5
# tar: ./279639.h5: file changed as we read it
# ./279829.h5
# tar: ./279829.h5: file changed as we read it
# ./279923.h5
# tar: ./279923.h5: file changed as we read it
# ./280049.h5
# tar: ./280049.h5: file changed as we read it
# ./280286.h5
# tar: ./280286.h5: file changed as we read it
# ./280599.h5
# tar: ./280599.h5: file changed as we read it
# ./280962.h5
# tar: ./280962.h5: file changed as we read it
# ./281156.h5
# tar: ./281156.h5: file changed as we read it
# ./281317.h5
# tar: ./281317.h5: file changed as we read it
# ./281640.h5
# tar: ./281640.h5: file changed as we read it
# ./281734.h5
# tar: ./281734.h5: file changed as we read it
# ./281761.h5
# tar: ./281761.h5: file changed as we read it
# ./281957.h5
# tar: ./281957.h5: file changed as we read it
# ./282050.h5
# tar: ./282050.h5: file changed as we read it
# ./282299.h5
# tar: ./282299.h5: file changed as we read it
# ./282322.h5
# tar: ./282322.h5: file changed as we read it
# ./282386.h5
# tar: ./282386.h5: file changed as we read it
# ./282585.h5
# tar: ./282585.h5: file changed as we read it
# ./282615.h5
# tar: ./282615.h5: file changed as we read it
# ./282640.h5
# tar: ./282640.h5: file changed as we read it
# ./282780.h5
# tar: ./282780.h5: file changed as we read it
# ./282902.h5
# tar: ./282902.h5: file changed as we read it
# ./282950.h5
# tar: ./282950.h5: file changed as we read it
# ./283007.h5
# tar: ./283007.h5: file changed as we read it
# ./283073.h5
# tar: ./283073.h5: file changed as we read it
# ./283102.h5
# tar: ./283102.h5: file changed as we read it
# ./283246.h5
# tar: ./283246.h5: file changed as we read it
# ./283340.h5
# tar: ./283340.h5: file changed as we read it
# ./283455.h5
# tar: ./283455.h5: file changed as we read it
# ./283518.h5
# tar: ./283518.h5: file changed as we read it
# ./283723.h5
# tar: ./283723.h5: file changed as we read it
# ./283725.h5
# tar: ./283725.h5: file changed as we read it
# ./283728.h5
# tar: ./283728.h5: file changed as we read it
# ./284006.h5
# tar: ./284006.h5: file changed as we read it
# ./284069.h5
# tar: ./284069.h5: file changed as we read it
# ./284110.h5
# tar: ./284110.h5: file changed as we read it
# ./284369.h5
# tar: ./284369.h5: file changed as we read it
# ./284395.h5
# tar: ./284395.h5: file changed as we read it
# ./284396.h5
# tar: ./284396.h5: file changed as we read it
# ./284406.h5
# tar: ./284406.h5: file changed as we read it
# ./284517.h5
# tar: ./284517.h5: file changed as we read it
# ./284590.h5
# tar: ./284590.h5: file changed as we read it
# ./284733.h5
# tar: ./284733.h5: file changed as we read it
# ./285049.h5
# tar: ./285049.h5: file changed as we read it
# ./285174.h5
# tar: ./285174.h5: file changed as we read it
# ./285230.h5
# tar: ./285230.h5: file changed as we read it
# ./285738.h5
# tar: ./285738.h5: file changed as we read it
# ./285987.h5
# tar: ./285987.h5: file changed as we read it
# ./286198.h5
# tar: ./286198.h5: file changed as we read it
# ./286376.h5
# tar: ./286376.h5: file changed as we read it
# ./286439.h5
# tar: ./286439.h5: file changed as we read it
# ./286588.h5
# tar: ./286588.h5: file changed as we read it
# ./286814.h5
# tar: ./286814.h5: file changed as we read it
# ./286847.h5
# tar: ./286847.h5: file changed as we read it
# ./286849.h5
# tar: ./286849.h5: file changed as we read it
# ./286937.h5
# tar: ./286937.h5: file changed as we read it
# ./286999.h5
# tar: ./286999.h5: file changed as we read it
# ./287085.h5
# tar: ./287085.h5: file changed as we read it
# ./287413.h5
# tar: ./287413.h5: file changed as we read it
# ./287530.h5
# tar: ./287530.h5: file changed as we read it
# ./287576.h5
# tar: ./287576.h5: file changed as we read it
# ./287599.h5
# tar: ./287599.h5: file changed as we read it
# ./287655.h5
# tar: ./287655.h5: file changed as we read it
# ./287656.h5
# tar: ./287656.h5: file changed as we read it
# ./287942.h5
# tar: ./287942.h5: file changed as we read it
# ./288061.h5
# tar: ./288061.h5: file changed as we read it
# ./288171.h5
# tar: ./288171.h5: file changed as we read it
# ./288216.h5
# tar: ./288216.h5: file changed as we read it
# ./288418.h5
# tar: ./288418.h5: file changed as we read it
# ./288446.h5
# tar: ./288446.h5: file changed as we read it
# ./288938.h5
# tar: ./288938.h5: file changed as we read it
# ./288977.h5
# tar: ./288977.h5: file changed as we read it
# ./289078.h5
# tar: ./289078.h5: file changed as we read it
# ./289351.h5
# tar: ./289351.h5: file changed as we read it
# ./289454.h5
# tar: ./289454.h5: file changed as we read it
# ./289640.h5
# tar: ./289640.h5: file changed as we read it
# ./289652.h5
# tar: ./289652.h5: file changed as we read it
# ./289663.h5
# tar: ./289663.h5: file changed as we read it
# ./289763.h5
# tar: ./289763.h5: file changed as we read it
# ./289905.h5
# tar: ./289905.h5: file changed as we read it
# ./289931.h5
# tar: ./289931.h5: file changed as we read it
# ./290004.h5
# tar: ./290004.h5: file changed as we read it
# ./290081.h5
# tar: ./290081.h5: file changed as we read it
# ./290095.h5
# tar: ./290095.h5: file changed as we read it
# ./290182.h5
# tar: ./290182.h5: file changed as we read it
# ./290256.h5
# tar: ./290256.h5: file changed as we read it
# ./290267.h5
# tar: ./290267.h5: file changed as we read it
# ./290371.h5
# tar: ./290371.h5: file changed as we read it
# ./290449.h5
# tar: ./290449.h5: file changed as we read it
# ./290450.h5
# tar: ./290450.h5: file changed as we read it
# ./290577.h5
# tar: ./290577.h5: file changed as we read it
# ./290750.h5
# tar: ./290750.h5: file changed as we read it
# ./290807.h5
# tar: ./290807.h5: file changed as we read it
# ./290988.h5
# tar: ./290988.h5: file changed as we read it
# ./291034.h5
# tar: ./291034.h5: file changed as we read it
# ./291191.h5
# tar: ./291191.h5: file changed as we read it
# ./291284.h5
# tar: ./291284.h5: file changed as we read it
# ./291286.h5
# tar: ./291286.h5: file changed as we read it
# ./291319.h5
# tar: ./291319.h5: file changed as we read it
# ./291333.h5
# tar: ./291333.h5: file changed as we read it
# ./291580.h5
# tar: ./291580.h5: file changed as we read it
# ./291582.h5
# tar: ./291582.h5: file changed as we read it
# ./291596.h5
# tar: ./291596.h5: file changed as we read it
# ./291607.h5
# tar: ./291607.h5: file changed as we read it
# ./291752.h5
# tar: ./291752.h5: file changed as we read it
# ./291765.h5
# tar: ./291765.h5: file changed as we read it
# ./291955.h5
# tar: ./291955.h5: file changed as we read it
# ./292043.h5
# tar: ./292043.h5: file changed as we read it
# ./292105.h5
# tar: ./292105.h5: file changed as we read it
# ./292106.h5
# tar: ./292106.h5: file changed as we read it
# ./292118.h5
# tar: ./292118.h5: file changed as we read it
# ./292173.h5
# tar: ./292173.h5: file changed as we read it
# ./292549.h5
# tar: ./292549.h5: file changed as we read it
# ./292591.h5
# tar: ./292591.h5: file changed as we read it
# ./292594.h5
# tar: ./292594.h5: file changed as we read it
# ./292722.h5
# tar: ./292722.h5: file changed as we read it
# ./292734.h5
# tar: ./292734.h5: file changed as we read it
# ./292746.h5
# tar: ./292746.h5: file changed as we read it
# ./292862.h5
# tar: ./292862.h5: file changed as we read it
# ./293076.h5
# tar: ./293076.h5: file changed as we read it
# ./293195.h5
# tar: ./293195.h5: file changed as we read it
# ./293211.h5
# tar: ./293211.h5: file changed as we read it
# ./293542.h5
# tar: ./293542.h5: file changed as we read it
# ./293864.h5
# tar: ./293864.h5: file changed as we read it
# ./293930.h5
# tar: ./293930.h5: file changed as we read it
# ./293966.h5
# tar: ./293966.h5: file changed as we read it
# ./293976.h5
# tar: ./293976.h5: file changed as we read it
# ./294037.h5
# tar: ./294037.h5: file changed as we read it
# ./294191.h5
# tar: ./294191.h5: file changed as we read it
# ./294206.h5
# tar: ./294206.h5: file changed as we read it
# ./294282.h5
# tar: ./294282.h5: file changed as we read it
# ./294426.h5
# tar: ./294426.h5: file changed as we read it
# ./294438.h5
# tar: ./294438.h5: file changed as we read it
# ./294480.h5
# tar: ./294480.h5: file changed as we read it
# ./294545.h5
# tar: ./294545.h5: file changed as we read it
# ./294764.h5
# tar: ./294764.h5: file changed as we read it
# ./294941.h5
# tar: ./294941.h5: file changed as we read it
# ./295080.h5
# tar: ./295080.h5: file changed as we read it
# ./295215.h5
# tar: ./295215.h5: file changed as we read it

# %% [markdown]
# #JPG Files

# %%
# !apt-get install pigz
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   pigz
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 63.6 kB of archives.
# After this operation, 162 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 pigz amd64 2.6-1 [63.6 kB]
# Fetched 63.6 kB in 0s (129 kB/s)
# Selecting previously unselected package pigz.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../archives/pigz_2.6-1_amd64.deb ...
# Unpacking pigz (2.6-1) ...
# Setting up pigz (2.6-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# Compress JPG images from both Train and Test datasets to save storage space in Google Drive

ROOT_JPGS = '/content/drive/MyDrive/Practicas_Profesionales/Data/JPGs'

# Define the path for the compressed archive containing both Train and Test image folders
tar_dir = os.path.join(ROOT_JPGS, 'Test&Train_JPGs.tar.gz')

# Create a highly compressed .tar.gz archive using pigz for better compression speed and efficiency
# !tar -cf - -C "/content/drive/MyDrive/Practicas_Profesionales/Data/JPGs" Train Test | pigz -9 -p 4 > "/content/drive/MyDrive/Practicas_Profesionales/Data/JPGs/Test&Train_JPGs.tar.gz"
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# tar: Train/27964.jpg: file changed as we read it
# tar: Train/27974.jpg: file changed as we read it
# tar: Train/28029.jpg: file changed as we read it
# tar: Train/28032.jpg: file changed as we read it
# tar: Train/28062.jpg: file changed as we read it
# tar: Train/28101.jpg: file changed as we read it
# tar: Train/28106.jpg: file changed as we read it
# tar: Train/28144.jpg: file changed as we read it
# tar: Train/28170.jpg: file changed as we read it
# tar: Train/28207.jpg: file changed as we read it
# tar: Train/28266.jpg: file changed as we read it
# tar: Train/28284.jpg: file changed as we read it
# tar: Train/28289.jpg: file changed as we read it
# tar: Train/28304.jpg: file changed as we read it
# tar: Train/28387.jpg: file changed as we read it
# tar: Train/28395.jpg: file changed as we read it
# tar: Train/28415.jpg: file changed as we read it
# tar: Train/28424.jpg: file changed as we read it
# tar: Train/28435.jpg: file changed as we read it
# tar: Train/28604.jpg: file changed as we read it
# tar: Train/28642.jpg: file changed as we read it
# tar: Train/28659.jpg: file changed as we read it
# tar: Train/28680.jpg: file changed as we read it
# tar: Train/28682.jpg: file changed as we read it
# tar: Train/28722.jpg: file changed as we read it
# tar: Train/28735.jpg: file changed as we read it
# tar: Train/28741.jpg: file changed as we read it
# tar: Train/28807.jpg: file changed as we read it
# tar: Train/28820.jpg: file changed as we read it
# tar: Train/28859.jpg: file changed as we read it
# tar: Train/28887.jpg: file changed as we read it
# tar: Train/28902.jpg: file changed as we read it
# tar: Train/28910.jpg: file changed as we read it
# tar: Train/28912.jpg: file changed as we read it
# tar: Train/29736.jpg: file changed as we read it
# tar: Train/29739.jpg: file changed as we read it
# tar: Train/29758.jpg: file changed as we read it
# tar: Train/29775.jpg: file changed as we read it
# tar: Train/29784.jpg: file changed as we read it
# tar: Test/228804.jpg: file changed as we read it
# tar: Test/228843.jpg: file changed as we read it
# tar: Test/228853.jpg: file changed as we read it
# tar: Test/228963.jpg: file changed as we read it
# tar: Test/229035.jpg: file changed as we read it
# tar: Test/229065.jpg: file changed as we read it
# tar: Test/229101.jpg: file changed as we read it
# tar: Test/229202.jpg: file changed as we read it
# tar: Test/229380.jpg: file changed as we read it
# tar: Test/229552.jpg: file changed as we read it
# tar: Test/229578.jpg: file changed as we read it
# tar: Test/229586.jpg: file changed as we read it
# tar: Test/229603.jpg: file changed as we read it
# tar: Test/229715.jpg: file changed as we read it
# tar: Test/229783.jpg: file changed as we read it
# tar: Test/229897.jpg: file changed as we read it
# tar: Test/229986.jpg: file changed as we read it
# tar: Test/229993.jpg: file changed as we read it
# tar: Test/230047.jpg: file changed as we read it
# tar: Test/230152.jpg: file changed as we read it
# tar: Test/230243.jpg: file changed as we read it
# tar: Test/230291.jpg: file changed as we read it
# tar: Test/230304.jpg: file changed as we read it
# tar: Test/230413.jpg: file changed as we read it
# tar: Test/230501.jpg: file changed as we read it
# tar: Test/230525.jpg: file changed as we read it
# tar: Test/230572.jpg: file changed as we read it
# tar: Test/230594.jpg: file changed as we read it
# tar: Test/230639.jpg: file changed as we read it
# tar: Test/230705.jpg: file changed as we read it
# tar: Test/230714.jpg: file changed as we read it
# tar: Test/230791.jpg: file changed as we read it
# tar: Test/230800.jpg: file changed as we read it
# tar: Test/230917.jpg: file changed as we read it
# tar: Test/230943.jpg: file changed as we read it
# tar: Test/230952.jpg: file changed as we read it
# tar: Test/230960.jpg: file changed as we read it
# tar: Test/230966.jpg: file changed as we read it
# tar: Test/231169.jpg: file changed as we read it
# tar: Test/231276.jpg: file changed as we read it
# tar: Test/231321.jpg: file changed as we read it
# tar: Test/231332.jpg: file changed as we read it
# tar: Test/231393.jpg: file changed as we read it
# tar: Test/231433.jpg: file changed as we read it
# tar: Test/231551.jpg: file changed as we read it
# tar: Test/231650.jpg: file changed as we read it
# tar: Test/231700.jpg: file changed as we read it
# tar: Test/231802.jpg: file changed as we read it
# tar: Test/231838.jpg: file changed as we read it
# tar: Test/231949.jpg: file changed as we read it
# tar: Test/231989.jpg: file changed as we read it
# tar: Test/232175.jpg: file changed as we read it
# tar: Test/232177.jpg: file changed as we read it
# tar: Test/232251.jpg: file changed as we read it
# tar: Test/232325.jpg: file changed as we read it
# tar: Test/232340.jpg: file changed as we read it
# tar: Test/232374.jpg: file changed as we read it
# tar: Test/232377.jpg: file changed as we read it
# tar: Test/232413.jpg: file changed as we read it
# tar: Test/232439.jpg: file changed as we read it
# tar: Test/232477.jpg: file changed as we read it
# tar: Test/232481.jpg: file changed as we read it
# tar: Test/232543.jpg: file changed as we read it
# tar: Test/232578.jpg: file changed as we read it
# tar: Test/232616.jpg: file changed as we read it
# tar: Test/232684.jpg: file changed as we read it
# tar: Test/232747.jpg: file changed as we read it
# tar: Test/232793.jpg: file changed as we read it
# tar: Test/232828.jpg: file changed as we read it
# tar: Test/232846.jpg: file changed as we read it
# tar: Test/232867.jpg: file changed as we read it
# tar: Test/232886.jpg: file changed as we read it
# tar: Test/232966.jpg: file changed as we read it
# tar: Test/233049.jpg: file changed as we read it
# tar: Test/233129.jpg: file changed as we read it
# tar: Test/233155.jpg: file changed as we read it
# tar: Test/233159.jpg: file changed as we read it
# tar: Test/233165.jpg: file changed as we read it
# tar: Test/233212.jpg: file changed as we read it
# tar: Test/233251.jpg: file changed as we read it
# tar: Test/233289.jpg: file changed as we read it
# tar: Test/233303.jpg: file changed as we read it
# tar: Test/233343.jpg: file changed as we read it
# tar: Test/233408.jpg: file changed as we read it
# tar: Test/233464.jpg: file changed as we read it
# tar: Test/233666.jpg: file changed as we read it
# tar: Test/233679.jpg: file changed as we read it
# tar: Test/233709.jpg: file changed as we read it
# tar: Test/233738.jpg: file changed as we read it
# tar: Test/233788.jpg: file changed as we read it
# tar: Test/233811.jpg: file changed as we read it
# tar: Test/233815.jpg: file changed as we read it
# tar: Test/233948.jpg: file changed as we read it
# tar: Test/234022.jpg: file changed as we read it
# tar: Test/234028.jpg: file changed as we read it
# tar: Test/234076.jpg: file changed as we read it
# tar: Test/234135.jpg: file changed as we read it
# tar: Test/234201.jpg: file changed as we read it
# tar: Test/234309.jpg: file changed as we read it
# tar: Test/234376.jpg: file changed as we read it
# tar: Test/234426.jpg: file changed as we read it
# tar: Test/234443.jpg: file changed as we read it
# tar: Test/234495.jpg: file changed as we read it
# tar: Test/234515.jpg: file changed as we read it
# tar: Test/234535.jpg: file changed as we read it
# tar: Test/234593.jpg: file changed as we read it
# tar: Test/234677.jpg: file changed as we read it
# tar: Test/234698.jpg: file changed as we read it
# tar: Test/234772.jpg: file changed as we read it
# tar: Test/234835.jpg: file changed as we read it
# tar: Test/234857.jpg: file changed as we read it
# tar: Test/234900.jpg: file changed as we read it
# tar: Test/234948.jpg: file changed as we read it
# tar: Test/235226.jpg: file changed as we read it
# tar: Test/235298.jpg: file changed as we read it
# tar: Test/235322.jpg: file changed as we read it
# tar: Test/235403.jpg: file changed as we read it
# tar: Test/235426.jpg: file changed as we read it
# tar: Test/235553.jpg: file changed as we read it
# tar: Test/235727.jpg: file changed as we read it
# tar: Test/235804.jpg: file changed as we read it
# tar: Test/235871.jpg: file changed as we read it
# tar: Test/235958.jpg: file changed as we read it
# tar: Test/235978.jpg: file changed as we read it
# tar: Test/236022.jpg: file changed as we read it
# tar: Test/236342.jpg: file changed as we read it
# tar: Test/236346.jpg: file changed as we read it
# tar: Test/236388.jpg: file changed as we read it
# tar: Test/236419.jpg: file changed as we read it
# tar: Test/236434.jpg: file changed as we read it
# tar: Test/236471.jpg: file changed as we read it
# tar: Test/236482.jpg: file changed as we read it
# tar: Test/236544.jpg: file changed as we read it
# tar: Test/236548.jpg: file changed as we read it
# tar: Test/236566.jpg: file changed as we read it
# tar: Test/236583.jpg: file changed as we read it
# tar: Test/236592.jpg: file changed as we read it
# tar: Test/236628.jpg: file changed as we read it
# tar: Test/236645.jpg: file changed as we read it
# tar: Test/236653.jpg: file changed as we read it
# tar: Test/236744.jpg: file changed as we read it
# tar: Test/236750.jpg: file changed as we read it
# tar: Test/236776.jpg: file changed as we read it
# tar: Test/236981.jpg: file changed as we read it
# tar: Test/236992.jpg: file changed as we read it
# tar: Test/237044.jpg: file changed as we read it
# tar: Test/237047.jpg: file changed as we read it
# tar: Test/237056.jpg: file changed as we read it
# tar: Test/237138.jpg: file changed as we read it
# tar: Test/237171.jpg: file changed as we read it
# tar: Test/237211.jpg: file changed as we read it
# tar: Test/237212.jpg: file changed as we read it
# tar: Test/237233.jpg: file changed as we read it
# tar: Test/237257.jpg: file changed as we read it
# tar: Test/237322.jpg: file changed as we read it
# tar: Test/237481.jpg: file changed as we read it
# tar: Test/237492.jpg: file changed as we read it
# tar: Test/237551.jpg: file changed as we read it
# tar: Test/237567.jpg: file changed as we read it
# tar: Test/237570.jpg: file changed as we read it
# tar: Test/237656.jpg: file changed as we read it
# tar: Test/237810.jpg: file changed as we read it
# tar: Test/237814.jpg: file changed as we read it
# tar: Test/237876.jpg: file changed as we read it
# tar: Test/237882.jpg: file changed as we read it
# tar: Test/237906.jpg: file changed as we read it
# tar: Test/238020.jpg: file changed as we read it
# tar: Test/238031.jpg: file changed as we read it
# tar: Test/238096.jpg: file changed as we read it
# tar: Test/238098.jpg: file changed as we read it
# tar: Test/238136.jpg: file changed as we read it
# tar: Test/238155.jpg: file changed as we read it
# tar: Test/238166.jpg: file changed as we read it
# tar: Test/238195.jpg: file changed as we read it
# tar: Test/238215.jpg: file changed as we read it
# tar: Test/238255.jpg: file changed as we read it
# tar: Test/238279.jpg: file changed as we read it
# tar: Test/238308.jpg: file changed as we read it
# tar: Test/238344.jpg: file changed as we read it
# tar: Test/238375.jpg: file changed as we read it
# tar: Test/238385.jpg: file changed as we read it
# tar: Test/238403.jpg: file changed as we read it
# tar: Test/238415.jpg: file changed as we read it
# tar: Test/238562.jpg: file changed as we read it
# tar: Test/238614.jpg: file changed as we read it
# tar: Test/238628.jpg: file changed as we read it
# tar: Test/238629.jpg: file changed as we read it
# tar: Test/238738.jpg: file changed as we read it
# tar: Test/238847.jpg: file changed as we read it
# tar: Test/238902.jpg: file changed as we read it
# tar: Test/238926.jpg: file changed as we read it
# tar: Test/238954.jpg: file changed as we read it
# tar: Test/239092.jpg: file changed as we read it
# tar: Test/239118.jpg: file changed as we read it
# tar: Test/239137.jpg: file changed as we read it
# tar: Test/239153.jpg: file changed as we read it
# tar: Test/239191.jpg: file changed as we read it
# tar: Test/239312.jpg: file changed as we read it
# tar: Test/239332.jpg: file changed as we read it
# tar: Test/239356.jpg: file changed as we read it
# tar: Test/239407.jpg: file changed as we read it
# tar: Test/239450.jpg: file changed as we read it
# tar: Test/239468.jpg: file changed as we read it
# tar: Test/239478.jpg: file changed as we read it
# tar: Test/239507.jpg: file changed as we read it
# tar: Test/239509.jpg: file changed as we read it
# tar: Test/239656.jpg: file changed as we read it
# tar: Test/239743.jpg: file changed as we read it
# tar: Test/239865.jpg: file changed as we read it
# tar: Test/239866.jpg: file changed as we read it
# tar: Test/239896.jpg: file changed as we read it
# tar: Test/239905.jpg: file changed as we read it
# tar: Test/239974.jpg: file changed as we read it
# tar: Test/240000.jpg: file changed as we read it
# tar: Test/240044.jpg: file changed as we read it
# tar: Test/240099.jpg: file changed as we read it
# tar: Test/240151.jpg: file changed as we read it
# tar: Test/240175.jpg: file changed as we read it
# tar: Test/240181.jpg: file changed as we read it
# tar: Test/240248.jpg: file changed as we read it
# tar: Test/240290.jpg: file changed as we read it
# tar: Test/240346.jpg: file changed as we read it
# tar: Test/240378.jpg: file changed as we read it
# tar: Test/240402.jpg: file changed as we read it
# tar: Test/240419.jpg: file changed as we read it
# tar: Test/240441.jpg: file changed as we read it
# tar: Test/240461.jpg: file changed as we read it
# tar: Test/240478.jpg: file changed as we read it
# tar: Test/240502.jpg: file changed as we read it
# tar: Test/240567.jpg: file changed as we read it
# tar: Test/240581.jpg: file changed as we read it
# tar: Test/240588.jpg: file changed as we read it
# tar: Test/240644.jpg: file changed as we read it
# tar: Test/240688.jpg: file changed as we read it
# tar: Test/240708.jpg: file changed as we read it
# tar: Test/240757.jpg: file changed as we read it
# tar: Test/240772.jpg: file changed as we read it
# tar: Test/240785.jpg: file changed as we read it
# tar: Test/240825.jpg: file changed as we read it
# tar: Test/240858.jpg: file changed as we read it
# tar: Test/240901.jpg: file changed as we read it
# tar: Test/241011.jpg: file changed as we read it
# tar: Test/241016.jpg: file changed as we read it
# tar: Test/241170.jpg: file changed as we read it
# tar: Test/241171.jpg: file changed as we read it
# tar: Test/241274.jpg: file changed as we read it
# tar: Test/241334.jpg: file changed as we read it
# tar: Test/241373.jpg: file changed as we read it
# tar: Test/241411.jpg: file changed as we read it
# tar: Test/241533.jpg: file changed as we read it
# tar: Test/241574.jpg: file changed as we read it
# tar: Test/241578.jpg: file changed as we read it
# tar: Test/241604.jpg: file changed as we read it
# tar: Test/241724.jpg: file changed as we read it
# tar: Test/241805.jpg: file changed as we read it
# tar: Test/241872.jpg: file changed as we read it
# tar: Test/241934.jpg: file changed as we read it
# tar: Test/242233.jpg: file changed as we read it
# tar: Test/242257.jpg: file changed as we read it
# tar: Test/242432.jpg: file changed as we read it
# tar: Test/242449.jpg: file changed as we read it
# tar: Test/242519.jpg: file changed as we read it
# tar: Test/242545.jpg: file changed as we read it
# tar: Test/242753.jpg: file changed as we read it
# tar: Test/242768.jpg: file changed as we read it
# tar: Test/242813.jpg: file changed as we read it
# tar: Test/242818.jpg: file changed as we read it
# tar: Test/242887.jpg: file changed as we read it
# tar: Test/242907.jpg: file changed as we read it
# tar: Test/242944.jpg: file changed as we read it
# tar: Test/242950.jpg: file changed as we read it
# tar: Test/243008.jpg: file changed as we read it
# tar: Test/243010.jpg: file changed as we read it
# tar: Test/243097.jpg: file changed as we read it
# tar: Test/243162.jpg: file changed as we read it
# tar: Test/243170.jpg: file changed as we read it
# tar: Test/243188.jpg: file changed as we read it
# tar: Test/243247.jpg: file changed as we read it
# tar: Test/243270.jpg: file changed as we read it
# tar: Test/243298.jpg: file changed as we read it
# tar: Test/243375.jpg: file changed as we read it
# tar: Test/243453.jpg: file changed as we read it
# tar: Test/243499.jpg: file changed as we read it
# tar: Test/243519.jpg: file changed as we read it
# tar: Test/243534.jpg: file changed as we read it
# tar: Test/243580.jpg: file changed as we read it
# tar: Test/243656.jpg: file changed as we read it
# tar: Test/243689.jpg: file changed as we read it
# tar: Test/243697.jpg: file changed as we read it
# tar: Test/243855.jpg: file changed as we read it
# tar: Test/243963.jpg: file changed as we read it
# tar: Test/244047.jpg: file changed as we read it
# tar: Test/244240.jpg: file changed as we read it
# tar: Test/244344.jpg: file changed as we read it
# tar: Test/244415.jpg: file changed as we read it
# tar: Test/244760.jpg: file changed as we read it
# tar: Test/244827.jpg: file changed as we read it
# tar: Test/245019.jpg: file changed as we read it
# tar: Test/245214.jpg: file changed as we read it
# tar: Test/245236.jpg: file changed as we read it
# tar: Test/245261.jpg: file changed as we read it
# tar: Test/245323.jpg: file changed as we read it
# tar: Test/245326.jpg: file changed as we read it
# tar: Test/245530.jpg: file changed as we read it
# tar: Test/245568.jpg: file changed as we read it
# tar: Test/245575.jpg: file changed as we read it
# tar: Test/245641.jpg: file changed as we read it
# tar: Test/245649.jpg: file changed as we read it
# tar: Test/250041.jpg: file changed as we read it
# tar: Test/245728.jpg: file changed as we read it
# tar: Test/250048.jpg: file changed as we read it
# tar: Test/250062.jpg: file changed as we read it
# tar: Test/250075.jpg: file changed as we read it
# tar: Test/245838.jpg: file changed as we read it
# tar: Test/245839.jpg: file changed as we read it
# tar: Test/255047.jpg: file changed as we read it
# tar: Test/245879.jpg: file changed as we read it
# tar: Test/255077.jpg: file changed as we read it
# tar: Test/250222.jpg: file changed as we read it
# tar: Test/245921.jpg: file changed as we read it
# tar: Test/255125.jpg: file changed as we read it
# tar: Test/250324.jpg: file changed as we read it
# tar: Test/246022.jpg: file changed as we read it
# tar: Test/250354.jpg: file changed as we read it
# tar: Test/250364.jpg: file changed as we read it
# tar: Test/250391.jpg: file changed as we read it
# tar: Test/246078.jpg: file changed as we read it
# tar: Test/246118.jpg: file changed as we read it
# tar: Test/250457.jpg: file changed as we read it
# tar: Test/255354.jpg: file changed as we read it
# tar: Test/255419.jpg: file changed as we read it
# tar: Test/255468.jpg: file changed as we read it
# tar: Test/255503.jpg: file changed as we read it
# tar: Test/250646.jpg: file changed as we read it
# tar: Test/246321.jpg: file changed as we read it
# tar: Test/255558.jpg: file changed as we read it
# tar: Test/255611.jpg: file changed as we read it
# tar: Test/250805.jpg: file changed as we read it
# tar: Test/250821.jpg: file changed as we read it
# tar: Test/255742.jpg: file changed as we read it
# tar: Test/255776.jpg: file changed as we read it
# tar: Test/250940.jpg: file changed as we read it
# tar: Test/255847.jpg: file changed as we read it
# tar: Test/251035.jpg: file changed as we read it
# tar: Test/251040.jpg: file changed as we read it
# tar: Test/255969.jpg: file changed as we read it
# tar: Test/251114.jpg: file changed as we read it
# tar: Test/251121.jpg: file changed as we read it
# tar: Test/246820.jpg: file changed as we read it
# tar: Test/256021.jpg: file changed as we read it
# tar: Test/251153.jpg: file changed as we read it
# tar: Test/246844.jpg: file changed as we read it
# tar: Test/246864.jpg: file changed as we read it
# tar: Test/251203.jpg: file changed as we read it
# tar: Test/251212.jpg: file changed as we read it
# tar: Test/256114.jpg: file changed as we read it
# tar: Test/251234.jpg: file changed as we read it
# tar: Test/246933.jpg: file changed as we read it
# tar: Test/256143.jpg: file changed as we read it
# tar: Test/251267.jpg: file changed as we read it
# tar: Test/256225.jpg: file changed as we read it
# tar: Test/256233.jpg: file changed as we read it
# tar: Test/251346.jpg: file changed as we read it
# tar: Test/256275.jpg: file changed as we read it
# tar: Test/247081.jpg: file changed as we read it
# tar: Test/256290.jpg: file changed as we read it
# tar: Test/247116.jpg: file changed as we read it
# tar: Test/251469.jpg: file changed as we read it
# tar: Test/247164.jpg: file changed as we read it
# tar: Test/251484.jpg: file changed as we read it
# tar: Test/247196.jpg: file changed as we read it
# tar: Test/247203.jpg: file changed as we read it
# tar: Test/251524.jpg: file changed as we read it
# tar: Test/247221.jpg: file changed as we read it
# tar: Test/247226.jpg: file changed as we read it
# tar: Test/256437.jpg: file changed as we read it
# tar: Test/251574.jpg: file changed as we read it
# tar: Test/256472.jpg: file changed as we read it
# tar: Test/247278.jpg: file changed as we read it
# tar: Test/256492.jpg: file changed as we read it
# tar: Test/247331.jpg: file changed as we read it
# tar: Test/251657.jpg: file changed as we read it
# tar: Test/247361.jpg: file changed as we read it
# tar: Test/247364.jpg: file changed as we read it
# tar: Test/256572.jpg: file changed as we read it
# tar: Test/247371.jpg: file changed as we read it
# tar: Test/247384.jpg: file changed as we read it
# tar: Test/247386.jpg: file changed as we read it
# tar: Test/256618.jpg: file changed as we read it
# tar: Test/256619.jpg: file changed as we read it
# tar: Test/247435.jpg: file changed as we read it
# tar: Test/251761.jpg: file changed as we read it
# tar: Test/256663.jpg: file changed as we read it
# tar: Test/251786.jpg: file changed as we read it
# tar: Test/256672.jpg: file changed as we read it
# tar: Test/247490.jpg: file changed as we read it
# tar: Test/247493.jpg: file changed as we read it
# tar: Test/256713.jpg: file changed as we read it
# tar: Test/256725.jpg: file changed as we read it
# tar: Test/247531.jpg: file changed as we read it
# tar: Test/247571.jpg: file changed as we read it
# tar: Test/256785.jpg: file changed as we read it
# tar: Test/251903.jpg: file changed as we read it
# tar: Test/251942.jpg: file changed as we read it
# tar: Test/251955.jpg: file changed as we read it
# tar: Test/251988.jpg: file changed as we read it
# tar: Test/247675.jpg: file changed as we read it
# tar: Test/251996.jpg: file changed as we read it
# tar: Test/252007.jpg: file changed as we read it
# tar: Test/252033.jpg: file changed as we read it
# tar: Test/247731.jpg: file changed as we read it
# tar: Test/256950.jpg: file changed as we read it
# tar: Test/256951.jpg: file changed as we read it
# tar: Test/252093.jpg: file changed as we read it
# tar: Test/256976.jpg: file changed as we read it
# tar: Test/257004.jpg: file changed as we read it
# tar: Test/257015.jpg: file changed as we read it
# tar: Test/247818.jpg: file changed as we read it
# tar: Test/252170.jpg: file changed as we read it
# tar: Test/257051.jpg: file changed as we read it
# tar: Test/257053.jpg: file changed as we read it
# tar: Test/252183.jpg: file changed as we read it
# tar: Test/252191.jpg: file changed as we read it
# tar: Test/257142.jpg: file changed as we read it
# tar: Test/257144.jpg: file changed as we read it
# tar: Test/257149.jpg: file changed as we read it
# tar: Test/248002.jpg: file changed as we read it
# tar: Test/257229.jpg: file changed as we read it
# tar: Test/257250.jpg: file changed as we read it
# tar: Test/248035.jpg: file changed as we read it
# tar: Test/252413.jpg: file changed as we read it
# tar: Test/248097.jpg: file changed as we read it
# tar: Test/257339.jpg: file changed as we read it
# tar: Test/252468.jpg: file changed as we read it
# tar: Test/252490.jpg: file changed as we read it
# tar: Test/248191.jpg: file changed as we read it
# tar: Test/252557.jpg: file changed as we read it
# tar: Test/252595.jpg: file changed as we read it
# tar: Test/248295.jpg: file changed as we read it
# tar: Test/257562.jpg: file changed as we read it
# tar: Test/252718.jpg: file changed as we read it
# tar: Test/248389.jpg: file changed as we read it
# tar: Test/252744.jpg: file changed as we read it
# tar: Test/252767.jpg: file changed as we read it
# tar: Test/252773.jpg: file changed as we read it
# tar: Test/257690.jpg: file changed as we read it
# tar: Test/252847.jpg: file changed as we read it
# tar: Test/257732.jpg: file changed as we read it
# tar: Test/248533.jpg: file changed as we read it
# tar: Test/252941.jpg: file changed as we read it
# tar: Test/252942.jpg: file changed as we read it
# tar: Test/248627.jpg: file changed as we read it
# tar: Test/252982.jpg: file changed as we read it
# tar: Test/257869.jpg: file changed as we read it
# tar: Test/248700.jpg: file changed as we read it
# tar: Test/248706.jpg: file changed as we read it
# tar: Test/248738.jpg: file changed as we read it
# tar: Test/248747.jpg: file changed as we read it
# tar: Test/257969.jpg: file changed as we read it
# tar: Test/253113.jpg: file changed as we read it
# tar: Test/253131.jpg: file changed as we read it
# tar: Test/253137.jpg: file changed as we read it
# tar: Test/253199.jpg: file changed as we read it
# tar: Test/258141.jpg: file changed as we read it
# tar: Test/253271.jpg: file changed as we read it
# tar: Test/258212.jpg: file changed as we read it
# tar: Test/253361.jpg: file changed as we read it
# tar: Test/249044.jpg: file changed as we read it
# tar: Test/258289.jpg: file changed as we read it
# tar: Test/249082.jpg: file changed as we read it
# tar: Test/249105.jpg: file changed as we read it
# tar: Test/258330.jpg: file changed as we read it
# tar: Test/258336.jpg: file changed as we read it
# tar: Test/258349.jpg: file changed as we read it
# tar: Test/249152.jpg: file changed as we read it
# tar: Test/258420.jpg: file changed as we read it
# tar: Test/253554.jpg: file changed as we read it
# tar: Test/253564.jpg: file changed as we read it
# tar: Test/258448.jpg: file changed as we read it
# tar: Test/253588.jpg: file changed as we read it
# tar: Test/258462.jpg: file changed as we read it
# tar: Test/249253.jpg: file changed as we read it
# tar: Test/258489.jpg: file changed as we read it
# tar: Test/253630.jpg: file changed as we read it
# tar: Test/249289.jpg: file changed as we read it
# tar: Test/249378.jpg: file changed as we read it
# tar: Test/258653.jpg: file changed as we read it
# tar: Test/258666.jpg: file changed as we read it
# tar: Test/253820.jpg: file changed as we read it
# tar: Test/258709.jpg: file changed as we read it
# tar: Test/253861.jpg: file changed as we read it
# tar: Test/249511.jpg: file changed as we read it
# tar: Test/258782.jpg: file changed as we read it
# tar: Test/249594.jpg: file changed as we read it
# tar: Test/253961.jpg: file changed as we read it
# tar: Test/249639.jpg: file changed as we read it
# tar: Test/249707.jpg: file changed as we read it
# tar: Test/258950.jpg: file changed as we read it
# tar: Test/258956.jpg: file changed as we read it
# tar: Test/254103.jpg: file changed as we read it
# tar: Test/254110.jpg: file changed as we read it
# tar: Test/249746.jpg: file changed as we read it
# tar: Test/254121.jpg: file changed as we read it
# tar: Test/259029.jpg: file changed as we read it
# tar: Test/259031.jpg: file changed as we read it
# tar: Test/254189.jpg: file changed as we read it
# tar: Test/259066.jpg: file changed as we read it
# tar: Test/249845.jpg: file changed as we read it
# tar: Test/259108.jpg: file changed as we read it
# tar: Test/254312.jpg: file changed as we read it
# tar: Test/259203.jpg: file changed as we read it
# tar: Test/254360.jpg: file changed as we read it
# tar: Test/259308.jpg: file changed as we read it
# tar: Test/254452.jpg: file changed as we read it
# tar: Test/259331.jpg: file changed as we read it
# tar: Test/254475.jpg: file changed as we read it
# tar: Test/259350.jpg: file changed as we read it
# tar: Test/259354.jpg: file changed as we read it
# tar: Test/259401.jpg: file changed as we read it
# tar: Test/254549.jpg: file changed as we read it
# tar: Test/254576.jpg: file changed as we read it
# tar: Test/254579.jpg: file changed as we read it
# tar: Test/254622.jpg: file changed as we read it
# tar: Test/259507.jpg: file changed as we read it
# tar: Test/254647.jpg: file changed as we read it
# tar: Test/259527.jpg: file changed as we read it
# tar: Test/259528.jpg: file changed as we read it
# tar: Test/254704.jpg: file changed as we read it
# tar: Test/259573.jpg: file changed as we read it
# tar: Test/259577.jpg: file changed as we read it
# tar: Test/254709.jpg: file changed as we read it
# tar: Test/259592.jpg: file changed as we read it
# tar: Test/254729.jpg: file changed as we read it
# tar: Test/254760.jpg: file changed as we read it
# tar: Test/254797.jpg: file changed as we read it
# tar: Test/254900.jpg: file changed as we read it
# tar: Test/259820.jpg: file changed as we read it
# tar: Test/259823.jpg: file changed as we read it
# tar: Test/259837.jpg: file changed as we read it
# tar: Test/254969.jpg: file changed as we read it
# tar: Test/259861.jpg: file changed as we read it
# tar: Test/259904.jpg: file changed as we read it
# tar: Test/259938.jpg: file changed as we read it
# tar: Test/259955.jpg: file changed as we read it
# tar: Test/260007.jpg: file changed as we read it
# tar: Test/265029.jpg: file changed as we read it
# tar: Test/265034.jpg: file changed as we read it
# tar: Test/260051.jpg: file changed as we read it
# tar: Test/260058.jpg: file changed as we read it
# tar: Test/265097.jpg: file changed as we read it
# tar: Test/260115.jpg: file changed as we read it
# tar: Test/265125.jpg: file changed as we read it
# tar: Test/260141.jpg: file changed as we read it
# tar: Test/260163.jpg: file changed as we read it
# tar: Test/270129.jpg: file changed as we read it
# tar: Test/265173.jpg: file changed as we read it
# tar: Test/270156.jpg: file changed as we read it
# tar: Test/265275.jpg: file changed as we read it
# tar: Test/265299.jpg: file changed as we read it
# tar: Test/270304.jpg: file changed as we read it
# tar: Test/265340.jpg: file changed as we read it
# tar: Test/265402.jpg: file changed as we read it
# tar: Test/265462.jpg: file changed as we read it
# tar: Test/265463.jpg: file changed as we read it
# tar: Test/265470.jpg: file changed as we read it
# tar: Test/270471.jpg: file changed as we read it
# tar: Test/265501.jpg: file changed as we read it
# tar: Test/265520.jpg: file changed as we read it
# tar: Test/270511.jpg: file changed as we read it
# tar: Test/265603.jpg: file changed as we read it
# tar: Test/270613.jpg: file changed as we read it
# tar: Test/270617.jpg: file changed as we read it
# tar: Test/270644.jpg: file changed as we read it
# tar: Test/265701.jpg: file changed as we read it
# tar: Test/265731.jpg: file changed as we read it
# tar: Test/265742.jpg: file changed as we read it
# tar: Test/270736.jpg: file changed as we read it
# tar: Test/270737.jpg: file changed as we read it
# tar: Test/265758.jpg: file changed as we read it
# tar: Test/270750.jpg: file changed as we read it
# tar: Test/265786.jpg: file changed as we read it
# tar: Test/265801.jpg: file changed as we read it
# tar: Test/265806.jpg: file changed as we read it
# tar: Test/270829.jpg: file changed as we read it
# tar: Test/260252.jpg: file changed as we read it
# tar: Test/270954.jpg: file changed as we read it
# tar: Test/266022.jpg: file changed as we read it
# tar: Test/260361.jpg: file changed as we read it
# tar: Test/271088.jpg: file changed as we read it
# tar: Test/260432.jpg: file changed as we read it
# tar: Test/260433.jpg: file changed as we read it
# tar: Test/271111.jpg: file changed as we read it
# tar: Test/260473.jpg: file changed as we read it
# tar: Test/260489.jpg: file changed as we read it
# tar: Test/266201.jpg: file changed as we read it
# tar: Test/260510.jpg: file changed as we read it
# tar: Test/266206.jpg: file changed as we read it
# tar: Test/266213.jpg: file changed as we read it
# tar: Test/271199.jpg: file changed as we read it
# tar: Test/271217.jpg: file changed as we read it
# tar: Test/266297.jpg: file changed as we read it
# tar: Test/266319.jpg: file changed as we read it
# tar: Test/266330.jpg: file changed as we read it
# tar: Test/266340.jpg: file changed as we read it
# tar: Test/260674.jpg: file changed as we read it
# tar: Test/260677.jpg: file changed as we read it
# tar: Test/271355.jpg: file changed as we read it
# tar: Test/260693.jpg: file changed as we read it
# tar: Test/266393.jpg: file changed as we read it
# tar: Test/266408.jpg: file changed as we read it
# tar: Test/266444.jpg: file changed as we read it
# tar: Test/271433.jpg: file changed as we read it
# tar: Test/271463.jpg: file changed as we read it
# tar: Test/260805.jpg: file changed as we read it
# tar: Test/266522.jpg: file changed as we read it
# tar: Test/271504.jpg: file changed as we read it
# tar: Test/271520.jpg: file changed as we read it
# tar: Test/260866.jpg: file changed as we read it
# tar: Test/271582.jpg: file changed as we read it
# tar: Test/260957.jpg: file changed as we read it
# tar: Test/260986.jpg: file changed as we read it
# tar: Test/271657.jpg: file changed as we read it
# tar: Test/261001.jpg: file changed as we read it
# tar: Test/261005.jpg: file changed as we read it
# tar: Test/266714.jpg: file changed as we read it
# tar: Test/261092.jpg: file changed as we read it
# tar: Test/266781.jpg: file changed as we read it
# tar: Test/271768.jpg: file changed as we read it
# tar: Test/261124.jpg: file changed as we read it
# tar: Test/266844.jpg: file changed as we read it
# tar: Test/261185.jpg: file changed as we read it
# tar: Test/266887.jpg: file changed as we read it
# tar: Test/271901.jpg: file changed as we read it
# tar: Test/266943.jpg: file changed as we read it
# tar: Test/261275.jpg: file changed as we read it
# tar: Test/271952.jpg: file changed as we read it
# tar: Test/261321.jpg: file changed as we read it
# tar: Test/261345.jpg: file changed as we read it
# tar: Test/267042.jpg: file changed as we read it
# tar: Test/267044.jpg: file changed as we read it
# tar: Test/261374.jpg: file changed as we read it
# tar: Test/267085.jpg: file changed as we read it
# tar: Test/261432.jpg: file changed as we read it
# tar: Test/267152.jpg: file changed as we read it
# tar: Test/272128.jpg: file changed as we read it
# tar: Test/272175.jpg: file changed as we read it
# tar: Test/267228.jpg: file changed as we read it
# tar: Test/272191.jpg: file changed as we read it
# tar: Test/272197.jpg: file changed as we read it
# tar: Test/261542.jpg: file changed as we read it
# tar: Test/261551.jpg: file changed as we read it
# tar: Test/267342.jpg: file changed as we read it
# tar: Test/261643.jpg: file changed as we read it
# tar: Test/272317.jpg: file changed as we read it
# tar: Test/267360.jpg: file changed as we read it
# tar: Test/272334.jpg: file changed as we read it
# tar: Test/272335.jpg: file changed as we read it
# tar: Test/272348.jpg: file changed as we read it
# tar: Test/261686.jpg: file changed as we read it
# tar: Test/261696.jpg: file changed as we read it
# tar: Test/267413.jpg: file changed as we read it
# tar: Test/261727.jpg: file changed as we read it
# tar: Test/272407.jpg: file changed as we read it
# tar: Test/267485.jpg: file changed as we read it
# tar: Test/261806.jpg: file changed as we read it
# tar: Test/272486.jpg: file changed as we read it
# tar: Test/267546.jpg: file changed as we read it
# tar: Test/272511.jpg: file changed as we read it
# tar: Test/267552.jpg: file changed as we read it
# tar: Test/267585.jpg: file changed as we read it
# tar: Test/272552.jpg: file changed as we read it
# tar: Test/272573.jpg: file changed as we read it
# tar: Test/267632.jpg: file changed as we read it
# tar: Test/267728.jpg: file changed as we read it
# tar: Test/262036.jpg: file changed as we read it
# tar: Test/267800.jpg: file changed as we read it
# tar: Test/272785.jpg: file changed as we read it
# tar: Test/262107.jpg: file changed as we read it
# tar: Test/272788.jpg: file changed as we read it
# tar: Test/272789.jpg: file changed as we read it
# tar: Test/262114.jpg: file changed as we read it
# tar: Test/272820.jpg: file changed as we read it
# tar: Test/267848.jpg: file changed as we read it
# tar: Test/262171.jpg: file changed as we read it
# tar: Test/272854.jpg: file changed as we read it
# tar: Test/267877.jpg: file changed as we read it
# tar: Test/262191.jpg: file changed as we read it
# tar: Test/272883.jpg: file changed as we read it
# tar: Test/262215.jpg: file changed as we read it
# tar: Test/272906.jpg: file changed as we read it
# tar: Test/267941.jpg: file changed as we read it
# tar: Test/272936.jpg: file changed as we read it
# tar: Test/262294.jpg: file changed as we read it
# tar: Test/268014.jpg: file changed as we read it
# tar: Test/262330.jpg: file changed as we read it
# tar: Test/273020.jpg: file changed as we read it
# tar: Test/273024.jpg: file changed as we read it
# tar: Test/262393.jpg: file changed as we read it
# tar: Test/268184.jpg: file changed as we read it
# tar: Test/273175.jpg: file changed as we read it
# tar: Test/273182.jpg: file changed as we read it
# tar: Test/273188.jpg: file changed as we read it
# tar: Test/268253.jpg: file changed as we read it
# tar: Test/273265.jpg: file changed as we read it
# tar: Test/273323.jpg: file changed as we read it
# tar: Test/273331.jpg: file changed as we read it
# tar: Test/262719.jpg: file changed as we read it
# tar: Test/268424.jpg: file changed as we read it
# tar: Test/273400.jpg: file changed as we read it
# tar: Test/268441.jpg: file changed as we read it
# tar: Test/273437.jpg: file changed as we read it
# tar: Test/262805.jpg: file changed as we read it
# tar: Test/273490.jpg: file changed as we read it
# tar: Test/262911.jpg: file changed as we read it
# tar: Test/268605.jpg: file changed as we read it
# tar: Test/273582.jpg: file changed as we read it
# tar: Test/273586.jpg: file changed as we read it
# tar: Test/273612.jpg: file changed as we read it
# tar: Test/273620.jpg: file changed as we read it
# tar: Test/262973.jpg: file changed as we read it
# tar: Test/273661.jpg: file changed as we read it
# tar: Test/268692.jpg: file changed as we read it
# tar: Test/263026.jpg: file changed as we read it
# tar: Test/268741.jpg: file changed as we read it
# tar: Test/268771.jpg: file changed as we read it
# tar: Test/263121.jpg: file changed as we read it
# tar: Test/268874.jpg: file changed as we read it
# tar: Test/263179.jpg: file changed as we read it
# tar: Test/263185.jpg: file changed as we read it
# tar: Test/263209.jpg: file changed as we read it
# tar: Test/263212.jpg: file changed as we read it
# tar: Test/263254.jpg: file changed as we read it
# tar: Test/263265.jpg: file changed as we read it
# tar: Test/263281.jpg: file changed as we read it
# tar: Test/263295.jpg: file changed as we read it
# tar: Test/263306.jpg: file changed as we read it
# tar: Test/269125.jpg: file changed as we read it
# tar: Test/263466.jpg: file changed as we read it
# tar: Test/269187.jpg: file changed as we read it
# tar: Test/263492.jpg: file changed as we read it
# tar: Test/269230.jpg: file changed as we read it
# tar: Test/269251.jpg: file changed as we read it
# tar: Test/269265.jpg: file changed as we read it
# tar: Test/263564.jpg: file changed as we read it
# tar: Test/263589.jpg: file changed as we read it
# tar: Test/269304.jpg: file changed as we read it
# tar: Test/263645.jpg: file changed as we read it
# tar: Test/263656.jpg: file changed as we read it
# tar: Test/263662.jpg: file changed as we read it
# tar: Test/269439.jpg: file changed as we read it
# tar: Test/263750.jpg: file changed as we read it
# tar: Test/269476.jpg: file changed as we read it
# tar: Test/269561.jpg: file changed as we read it
# tar: Test/263865.jpg: file changed as we read it
# tar: Test/269618.jpg: file changed as we read it
# tar: Test/269714.jpg: file changed as we read it
# tar: Test/264033.jpg: file changed as we read it
# tar: Test/269810.jpg: file changed as we read it
# tar: Test/269828.jpg: file changed as we read it
# tar: Test/264120.jpg: file changed as we read it
# tar: Test/264128.jpg: file changed as we read it
# tar: Test/264134.jpg: file changed as we read it
# tar: Test/269844.jpg: file changed as we read it
# tar: Test/264161.jpg: file changed as we read it
# tar: Test/264164.jpg: file changed as we read it
# tar: Test/264211.jpg: file changed as we read it
# tar: Test/269935.jpg: file changed as we read it
# tar: Test/269982.jpg: file changed as we read it
# tar: Test/264369.jpg: file changed as we read it
# tar: Test/264390.jpg: file changed as we read it
# tar: Test/264460.jpg: file changed as we read it
# tar: Test/264470.jpg: file changed as we read it
# tar: Test/264552.jpg: file changed as we read it
# tar: Test/264582.jpg: file changed as we read it
# tar: Test/264605.jpg: file changed as we read it
# tar: Test/264630.jpg: file changed as we read it
# tar: Test/264642.jpg: file changed as we read it
# tar: Test/264806.jpg: file changed as we read it
# tar: Test/264807.jpg: file changed as we read it
# tar: Test/264890.jpg: file changed as we read it
# tar: Test/264907.jpg: file changed as we read it
# tar: Test/264933.jpg: file changed as we read it
# tar: Test/273867.jpg: file changed as we read it
# tar: Test/273891.jpg: file changed as we read it
# tar: Test/273982.jpg: file changed as we read it
# tar: Test/274055.jpg: file changed as we read it
# tar: Test/274369.jpg: file changed as we read it
# tar: Test/274385.jpg: file changed as we read it
# tar: Test/274417.jpg: file changed as we read it
# tar: Test/274419.jpg: file changed as we read it
# tar: Test/274472.jpg: file changed as we read it
# tar: Test/274598.jpg: file changed as we read it
# tar: Test/274671.jpg: file changed as we read it
# tar: Test/274880.jpg: file changed as we read it
# tar: Test/274883.jpg: file changed as we read it
# tar: Test/274899.jpg: file changed as we read it
# tar: Test/275058.jpg: file changed as we read it
# tar: Test/275060.jpg: file changed as we read it
# tar: Test/275082.jpg: file changed as we read it
# tar: Test/275365.jpg: file changed as we read it
# tar: Test/275471.jpg: file changed as we read it
# tar: Test/275529.jpg: file changed as we read it
# tar: Test/275544.jpg: file changed as we read it
# tar: Test/275709.jpg: file changed as we read it
# tar: Test/275758.jpg: file changed as we read it
# tar: Test/275878.jpg: file changed as we read it
# tar: Test/275891.jpg: file changed as we read it
# tar: Test/276112.jpg: file changed as we read it
# tar: Test/276148.jpg: file changed as we read it
# tar: Test/276309.jpg: file changed as we read it
# tar: Test/276384.jpg: file changed as we read it
# tar: Test/276467.jpg: file changed as we read it
# tar: Test/276641.jpg: file changed as we read it
# tar: Test/276659.jpg: file changed as we read it
# tar: Test/276671.jpg: file changed as we read it
# tar: Test/276746.jpg: file changed as we read it
# tar: Test/276765.jpg: file changed as we read it
# tar: Test/276792.jpg: file changed as we read it
# tar: Test/276853.jpg: file changed as we read it
# tar: Test/276886.jpg: file changed as we read it
# tar: Test/277115.jpg: file changed as we read it
# tar: Test/277138.jpg: file changed as we read it
# tar: Test/277159.jpg: file changed as we read it
# tar: Test/277263.jpg: file changed as we read it
# tar: Test/277477.jpg: file changed as we read it
# tar: Test/277520.jpg: file changed as we read it
# tar: Test/277595.jpg: file changed as we read it
# tar: Test/277634.jpg: file changed as we read it
# tar: Test/277685.jpg: file changed as we read it
# tar: Test/277756.jpg: file changed as we read it
# tar: Test/277830.jpg: file changed as we read it
# tar: Test/277844.jpg: file changed as we read it
# tar: Test/277995.jpg: file changed as we read it
# tar: Test/278245.jpg: file changed as we read it
# tar: Test/278318.jpg: file changed as we read it
# tar: Test/278409.jpg: file changed as we read it
# tar: Test/278471.jpg: file changed as we read it
# tar: Test/278557.jpg: file changed as we read it
# tar: Test/278777.jpg: file changed as we read it
# tar: Test/278879.jpg: file changed as we read it
# tar: Test/278905.jpg: file changed as we read it
# tar: Test/278937.jpg: file changed as we read it
# tar: Test/279100.jpg: file changed as we read it
# tar: Test/279511.jpg: file changed as we read it
# tar: Test/279513.jpg: file changed as we read it
# tar: Test/279639.jpg: file changed as we read it
# tar: Test/279829.jpg: file changed as we read it
# tar: Test/279923.jpg: file changed as we read it
# tar: Test/280049.jpg: file changed as we read it
# tar: Test/280286.jpg: file changed as we read it
# tar: Test/280599.jpg: file changed as we read it
# tar: Test/280962.jpg: file changed as we read it
# tar: Test/281156.jpg: file changed as we read it
# tar: Test/281317.jpg: file changed as we read it
# tar: Test/281640.jpg: file changed as we read it
# tar: Test/281734.jpg: file changed as we read it
# tar: Test/281761.jpg: file changed as we read it
# tar: Test/281957.jpg: file changed as we read it
# tar: Test/282050.jpg: file changed as we read it
# tar: Test/282299.jpg: file changed as we read it
# tar: Test/282322.jpg: file changed as we read it
# tar: Test/282386.jpg: file changed as we read it
# tar: Test/282585.jpg: file changed as we read it
# tar: Test/282615.jpg: file changed as we read it
# tar: Test/282640.jpg: file changed as we read it
# tar: Test/282780.jpg: file changed as we read it
# tar: Test/282902.jpg: file changed as we read it
# tar: Test/282950.jpg: file changed as we read it
# tar: Test/283007.jpg: file changed as we read it
# tar: Test/283073.jpg: file changed as we read it
# tar: Test/283102.jpg: file changed as we read it
# tar: Test/283246.jpg: file changed as we read it
# tar: Test/283340.jpg: file changed as we read it
# tar: Test/283455.jpg: file changed as we read it
# tar: Test/283518.jpg: file changed as we read it
# tar: Test/283723.jpg: file changed as we read it
# tar: Test/283725.jpg: file changed as we read it
# tar: Test/283728.jpg: file changed as we read it
# tar: Test/284006.jpg: file changed as we read it
# tar: Test/284069.jpg: file changed as we read it
# tar: Test/284110.jpg: file changed as we read it
# tar: Test/284369.jpg: file changed as we read it
# tar: Test/284395.jpg: file changed as we read it
# tar: Test/284396.jpg: file changed as we read it
# tar: Test/284406.jpg: file changed as we read it
# tar: Test/284517.jpg: file changed as we read it
# tar: Test/284590.jpg: file changed as we read it
# tar: Test/284733.jpg: file changed as we read it
# tar: Test/285049.jpg: file changed as we read it
# tar: Test/285174.jpg: file changed as we read it
# tar: Test/285230.jpg: file changed as we read it
# tar: Test/285738.jpg: file changed as we read it
# tar: Test/285987.jpg: file changed as we read it
# tar: Test/286198.jpg: file changed as we read it
# tar: Test/286376.jpg: file changed as we read it
# tar: Test/286439.jpg: file changed as we read it
# tar: Test/286588.jpg: file changed as we read it
# tar: Test/286814.jpg: file changed as we read it
# tar: Test/286847.jpg: file changed as we read it
# tar: Test/286849.jpg: file changed as we read it
# tar: Test/286937.jpg: file changed as we read it
# tar: Test/286999.jpg: file changed as we read it
# tar: Test/287085.jpg: file changed as we read it
# tar: Test/287413.jpg: file changed as we read it
# tar: Test/287530.jpg: file changed as we read it
# tar: Test/287576.jpg: file changed as we read it
# tar: Test/287599.jpg: file changed as we read it
# tar: Test/287655.jpg: file changed as we read it
# tar: Test/287656.jpg: file changed as we read it
# tar: Test/287942.jpg: file changed as we read it
# tar: Test/288061.jpg: file changed as we read it
# tar: Test/288171.jpg: file changed as we read it
# tar: Test/288216.jpg: file changed as we read it
# tar: Test/288418.jpg: file changed as we read it
# tar: Test/288446.jpg: file changed as we read it
# tar: Test/288938.jpg: file changed as we read it
# tar: Test/288977.jpg: file changed as we read it
# tar: Test/289078.jpg: file changed as we read it
# tar: Test/289351.jpg: file changed as we read it
# tar: Test/289454.jpg: file changed as we read it
# tar: Test/289640.jpg: file changed as we read it
# tar: Test/289652.jpg: file changed as we read it
# tar: Test/289663.jpg: file changed as we read it
# tar: Test/289763.jpg: file changed as we read it
# tar: Test/289905.jpg: file changed as we read it
# tar: Test/289931.jpg: file changed as we read it
# tar: Test/290004.jpg: file changed as we read it
# tar: Test/290081.jpg: file changed as we read it
# tar: Test/290095.jpg: file changed as we read it
# tar: Test/290182.jpg: file changed as we read it
# tar: Test/290256.jpg: file changed as we read it
# tar: Test/290267.jpg: file changed as we read it
# tar: Test/290371.jpg: file changed as we read it
# tar: Test/290449.jpg: file changed as we read it
# tar: Test/290450.jpg: file changed as we read it
# tar: Test/290577.jpg: file changed as we read it
# tar: Test/290750.jpg: file changed as we read it
# tar: Test/290807.jpg: file changed as we read it
# tar: Test/290988.jpg: file changed as we read it
# ...
# tar: Test/40076.jpg: file changed as we read it
# tar: Test/40103.jpg: file changed as we read it
# tar: Test/40115.jpg: file changed as we read it
# tar: Test/40265.jpg: file changed as we read it
# tar: Test/40310.jpg: file changed as we read it
# tar: Test/40315.jpg: file changed as we read it
# tar: Test/40360.jpg: file changed as we read it
# tar: Test/40372.jpg: file changed as we read it
# tar: Test/40439.jpg: file changed as we read it
# tar: Test/40463.jpg: file changed as we read it
# tar: Test/40504.jpg: file changed as we read it
# tar: Test/40563.jpg: file changed as we read it
# tar: Test/40571.jpg: file changed as we read it
# tar: Test/40653.jpg: file changed as we read it
# tar: Test/40691.jpg: file changed as we read it
# tar: Test/40812.jpg: file changed as we read it
# tar: Test/40955.jpg: file changed as we read it
# tar: Test/40962.jpg: file changed as we read it
# tar: Test/41031.jpg: file changed as we read it
# tar: Test/41038.jpg: file changed as we read it
# tar: Test/41115.jpg: file changed as we read it
# tar: Test/41151.jpg: file changed as we read it
# tar: Test/41171.jpg: file changed as we read it
# tar: Test/41217.jpg: file changed as we read it
# tar: Test/41262.jpg: file changed as we read it
# tar: Test/41293.jpg: file changed as we read it
# tar: Test/41411.jpg: file changed as we read it
# tar: Test/41418.jpg: file changed as we read it
# tar: Test/41507.jpg: file changed as we read it
# tar: Test/41517.jpg: file changed as we read it
# tar: Test/41554.jpg: file changed as we read it
# tar: Test/41596.jpg: file changed as we read it
# tar: Test/41614.jpg: file changed as we read it
# tar: Test/41630.jpg: file changed as we read it
# tar: Test/41723.jpg: file changed as we read it
# tar: Test/41730.jpg: file changed as we read it
# tar: Test/41742.jpg: file changed as we read it
# tar: Test/41750.jpg: file changed as we read it
# tar: Test/41778.jpg: file changed as we read it
# tar: Test/41777.jpg: file changed as we read it
# tar: Test/41835.jpg: file changed as we read it
# tar: Test/41963.jpg: file changed as we read it
# tar: Test/42020.jpg: file changed as we read it
# tar: Test/42102.jpg: file changed as we read it
# tar: Test/42112.jpg: file changed as we read it
# tar: Test/42125.jpg: file changed as we read it
# tar: Test/42130.jpg: file changed as we read it
# tar: Test/42263.jpg: file changed as we read it
# tar: Test/42311.jpg: file changed as we read it
# tar: Test/43718.jpg: file changed as we read it
# tar: Test/43739.jpg: file changed as we read it
# tar: Test/43741.jpg: file changed as we read it
# tar: Test/43802.jpg: file changed as we read it
# tar: Test/43866.jpg: file changed as we read it
# tar: Test/44041.jpg: file changed as we read it
# tar: Test/44059.jpg: file changed as we read it
# tar: Test/44321.jpg: file changed as we read it
# tar: Test/44374.jpg: file changed as we read it
# tar: Test/44384.jpg: file changed as we read it
# tar: Test/44445.jpg: file changed as we read it
# tar: Test/44461.jpg: file changed as we read it
# tar: Test/44607.jpg: file changed as we read it
# tar: Test/44743.jpg: file changed as we read it
# tar: Test/44845.jpg: file changed as we read it
# tar: Test/44873.jpg: file changed as we read it
# tar: Test/44884.jpg: file changed as we read it
# tar: Test/44896.jpg: file changed as we read it
# tar: Test/44904.jpg: file changed as we read it
# tar: Test/44908.jpg: file changed as we read it
# tar: Test/45039.jpg: file changed as we read it
# tar: Test/45049.jpg: file changed as we read it
# tar: Test/45213.jpg: file changed as we read it
# tar: Test/45222.jpg: file changed as we read it
# tar: Test/45280.jpg: file changed as we read it
# tar: Test/45408.jpg: file changed as we read it
# tar: Test/45420.jpg: file changed as we read it
# tar: Test/45469.jpg: file changed as we read it
# tar: Test/45470.jpg: file changed as we read it
# tar: Test/45562.jpg: file changed as we read it
# tar: Test/45623.jpg: file changed as we read it
# tar: Test/45630.jpg: file changed as we read it
# tar: Test/45710.jpg: file changed as we read it
# tar: Test/45751.jpg: file changed as we read it
# tar: Test/45779.jpg: file changed as we read it
# tar: Test/45915.jpg: file changed as we read it
# tar: Test/46165.jpg: file changed as we read it
# tar: Test/46196.jpg: file changed as we read it
# tar: Test/46203.jpg: file changed as we read it
# tar: Test/46242.jpg: file changed as we read it
# tar: Test/46257.jpg: file changed as we read it
# tar: Test/46265.jpg: file changed as we read it
# tar: Test/46271.jpg: file changed as we read it
# tar: Test/46309.jpg: file changed as we read it
# tar: Test/46332.jpg: file changed as we read it
# tar: Test/46357.jpg: file changed as we read it
# tar: Test/46384.jpg: file changed as we read it
# tar: Test/46408.jpg: file changed as we read it
# tar: Test/46413.jpg: file changed as we read it
# tar: Test/46426.jpg: file changed as we read it
# tar: Test/46472.jpg: file changed as we read it
# tar: Test/46505.jpg: file changed as we read it
# tar: Test/46523.jpg: file changed as we read it
# tar: Test/46540.jpg: file changed as we read it
# tar: Test/46596.jpg: file changed as we read it
# tar: Test/46692.jpg: file changed as we read it
# tar: Test/46698.jpg: file changed as we read it
# tar: Test/46771.jpg: file changed as we read it
# tar: Test/46819.jpg: file changed as we read it
# tar: Test/46825.jpg: file changed as we read it
# tar: Test/46861.jpg: file changed as we read it
# tar: Test/46943.jpg: file changed as we read it
# tar: Test/46973.jpg: file changed as we read it
# tar: Test/46989.jpg: file changed as we read it
# tar: Test/47049.jpg: file changed as we read it
# tar: Test/47147.jpg: file changed as we read it
# tar: Test/47353.jpg: file changed as we read it
# tar: Test/47359.jpg: file changed as we read it
# tar: Test/47482.jpg: file changed as we read it
# tar: Test/47563.jpg: file changed as we read it
# tar: Test/47575.jpg: file changed as we read it
# tar: Test/47597.jpg: file changed as we read it
# tar: Test/47607.jpg: file changed as we read it
# tar: Test/47665.jpg: file changed as we read it
# tar: Test/47797.jpg: file changed as we read it
# tar: Test/47814.jpg: file changed as we read it
# tar: Test/47870.jpg: file changed as we read it
# tar: Test/47881.jpg: file changed as we read it
# tar: Test/47915.jpg: file changed as we read it
# tar: Test/47944.jpg: file changed as we read it
# tar: Test/48006.jpg: file changed as we read it
# tar: Test/48149.jpg: file changed as we read it
# tar: Test/48197.jpg: file changed as we read it
# tar: Test/48274.jpg: file changed as we read it
# tar: Test/48331.jpg: file changed as we read it
# tar: Test/48386.jpg: file changed as we read it
# tar: Test/48395.jpg: file changed as we read it
# tar: Test/48483.jpg: file changed as we read it
# tar: Test/48549.jpg: file changed as we read it
# tar: Test/48580.jpg: file changed as we read it
# tar: Test/48634.jpg: file changed as we read it
# tar: Test/48646.jpg: file changed as we read it
# tar: Test/48788.jpg: file changed as we read it
# tar: Test/48795.jpg: file changed as we read it
# tar: Test/48837.jpg: file changed as we read it
# tar: Test/48856.jpg: file changed as we read it
# tar: Test/48878.jpg: file changed as we read it
# tar: Test/48900.jpg: file changed as we read it
# tar: Test/48960.jpg: file changed as we read it
# tar: Test/48997.jpg: file changed as we read it
# tar: Test/49044.jpg: file changed as we read it
# tar: Test/49134.jpg: file changed as we read it
# tar: Test/49165.jpg: file changed as we read it
# tar: Test/49170.jpg: file changed as we read it
# tar: Test/49174.jpg: file changed as we read it
# tar: Test/49217.jpg: file changed as we read it
# tar: Test/49222.jpg: file changed as we read it
# tar: Test/49229.jpg: file changed as we read it
# tar: Test/49243.jpg: file changed as we read it
# tar: Test/49268.jpg: file changed as we read it
# tar: Test/49306.jpg: file changed as we read it
# tar: Test/49332.jpg: file changed as we read it
# tar: Test/49421.jpg: file changed as we read it
# tar: Test/49634.jpg: file changed as we read it
# tar: Test/49654.jpg: file changed as we read it
# tar: Test/49662.jpg: file changed as we read it
# tar: Test/49699.jpg: file changed as we read it
# tar: Test/49708.jpg: file changed as we read it
# tar: Test/49722.jpg: file changed as we read it
# tar: Test/49775.jpg: file changed as we read it
# tar: Test/49821.jpg: file changed as we read it
# tar: Test/49833.jpg: file changed as we read it
# tar: Test/49939.jpg: file changed as we read it
# tar: Test/49996.jpg: file changed as we read it
# tar: Test/50128.jpg: file changed as we read it
# tar: Test/50151.jpg: file changed as we read it
# tar: Test/50175.jpg: file changed as we read it
# tar: Test/50233.jpg: file changed as we read it
# tar: Test/50421.jpg: file changed as we read it
# tar: Test/50566.jpg: file changed as we read it
# tar: Test/50582.jpg: file changed as we read it
# tar: Test/50652.jpg: file changed as we read it
# tar: Test/50740.jpg: file changed as we read it
# tar: Test/50877.jpg: file changed as we read it
# tar: Test/50991.jpg: file changed as we read it
# tar: Test/51016.jpg: file changed as we read it
# tar: Test/51028.jpg: file changed as we read it
# tar: Test/51250.jpg: file changed as we read it
# tar: Test/51333.jpg: file changed as we read it
# tar: Test/51430.jpg: file changed as we read it
# tar: Test/51487.jpg: file changed as we read it
# tar: Test/51491.jpg: file changed as we read it
# tar: Test/51562.jpg: file changed as we read it
# tar: Test/51605.jpg: file changed as we read it
# tar: Test/51675.jpg: file changed as we read it
# tar: Test/51745.jpg: file changed as we read it
# tar: Test/51754.jpg: file changed as we read it
# tar: Test/51811.jpg: file changed as we read it
# tar: Test/51816.jpg: file changed as we read it
# tar: Test/51818.jpg: file changed as we read it
# tar: Test/51888.jpg: file changed as we read it
# tar: Test/51911.jpg: file changed as we read it
# tar: Test/51913.jpg: file changed as we read it
# tar: Test/51956.jpg: file changed as we read it
# tar: Test/51967.jpg: file changed as we read it
# tar: Test/52026.jpg: file changed as we read it
# tar: Test/52192.jpg: file changed as we read it
# tar: Test/52223.jpg: file changed as we read it
# tar: Test/52247.jpg: file changed as we read it
# tar: Test/52249.jpg: file changed as we read it
# tar: Test/52288.jpg: file changed as we read it
# tar: Test/52362.jpg: file changed as we read it
# tar: Test/52386.jpg: file changed as we read it
# tar: Test/52491.jpg: file changed as we read it
# tar: Test/52561.jpg: file changed as we read it
# tar: Test/52560.jpg: file changed as we read it
# tar: Test/52592.jpg: file changed as we read it
# tar: Test/52683.jpg: file changed as we read it
# tar: Test/52689.jpg: file changed as we read it
# tar: Test/52704.jpg: file changed as we read it
# tar: Test/52858.jpg: file changed as we read it
# tar: Test/52952.jpg: file changed as we read it
# tar: Test/52998.jpg: file changed as we read it
# tar: Test/53035.jpg: file changed as we read it
# tar: Test/53079.jpg: file changed as we read it
# tar: Test/53082.jpg: file changed as we read it
# tar: Test/53154.jpg: file changed as we read it
# tar: Test/53207.jpg: file changed as we read it
# tar: Test/53254.jpg: file changed as we read it
# tar: Test/53280.jpg: file changed as we read it
# tar: Test/53463.jpg: file changed as we read it
# tar: Test/53480.jpg: file changed as we read it
# tar: Test/53488.jpg: file changed as we read it
# tar: Test/53493.jpg: file changed as we read it
# tar: Test/53519.jpg: file changed as we read it
# tar: Test/53644.jpg: file changed as we read it
# tar: Test/53656.jpg: file changed as we read it
# tar: Test/53695.jpg: file changed as we read it
# tar: Test/53747.jpg: file changed as we read it
# tar: Test/53759.jpg: file changed as we read it
# tar: Test/53813.jpg: file changed as we read it
# tar: Test/53827.jpg: file changed as we read it
# tar: Test/53831.jpg: file changed as we read it
# tar: Test/53847.jpg: file changed as we read it
# tar: Test/53857.jpg: file changed as we read it
# tar: Test/53904.jpg: file changed as we read it
# tar: Test/54045.jpg: file changed as we read it
# tar: Test/54149.jpg: file changed as we read it
# tar: Test/54264.jpg: file changed as we read it
# tar: Test/54287.jpg: file changed as we read it
# tar: Test/54310.jpg: file changed as we read it
# tar: Test/54321.jpg: file changed as we read it
# tar: Test/54352.jpg: file changed as we read it
# tar: Test/54365.jpg: file changed as we read it
# tar: Test/54386.jpg: file changed as we read it
# tar: Test/54464.jpg: file changed as we read it
# tar: Test/54477.jpg: file changed as we read it
# tar: Test/54518.jpg: file changed as we read it
# tar: Test/54549.jpg: file changed as we read it
# tar: Test/54713.jpg: file changed as we read it
# tar: Test/54760.jpg: file changed as we read it
# tar: Test/54804.jpg: file changed as we read it
# tar: Test/54876.jpg: file changed as we read it
# tar: Test/54882.jpg: file changed as we read it
# tar: Test/54893.jpg: file changed as we read it
# tar: Test/54931.jpg: file changed as we read it
# tar: Test/54968.jpg: file changed as we read it
# tar: Test/54988.jpg: file changed as we read it
# tar: Test/55087.jpg: file changed as we read it
# tar: Test/55140.jpg: file changed as we read it
# tar: Test/55213.jpg: file changed as we read it
# tar: Test/55245.jpg: file changed as we read it
# tar: Test/55287.jpg: file changed as we read it
# tar: Test/55320.jpg: file changed as we read it
# tar: Test/55322.jpg: file changed as we read it
# tar: Test/55331.jpg: file changed as we read it
# tar: Test/55544.jpg: file changed as we read it
# tar: Test/55545.jpg: file changed as we read it
# tar: Test/55637.jpg: file changed as we read it
# tar: Test/55731.jpg: file changed as we read it
# tar: Test/55834.jpg: file changed as we read it
# tar: Test/55838.jpg: file changed as we read it
# tar: Test/55858.jpg: file changed as we read it
# tar: Test/56044.jpg: file changed as we read it
# tar: Test/56048.jpg: file changed as we read it
# tar: Test/56083.jpg: file changed as we read it
# tar: Test/56106.jpg: file changed as we read it
# tar: Test/56215.jpg: file changed as we read it
# tar: Test/56239.jpg: file changed as we read it
# tar: Test/56277.jpg: file changed as we read it
# tar: Test/56310.jpg: file changed as we read it
# tar: Test/56325.jpg: file changed as we read it
# tar: Test/56387.jpg: file changed as we read it
# tar: Test/56400.jpg: file changed as we read it
# tar: Test/56467.jpg: file changed as we read it
# tar: Test/56558.jpg: file changed as we read it
# tar: Test/56599.jpg: file changed as we read it
# tar: Test/56618.jpg: file changed as we read it
# tar: Test/56667.jpg: file changed as we read it
# tar: Test/56742.jpg: file changed as we read it
# tar: Test/56757.jpg: file changed as we read it
# tar: Test/56883.jpg: file changed as we read it
# tar: Test/56932.jpg: file changed as we read it
# tar: Test/57079.jpg: file changed as we read it
# tar: Test/57133.jpg: file changed as we read it
# tar: Test/57135.jpg: file changed as we read it
# tar: Test/57136.jpg: file changed as we read it
# tar: Test/57139.jpg: file changed as we read it
# tar: Test/57202.jpg: file changed as we read it
# tar: Test/57215.jpg: file changed as we read it
# tar: Test/57289.jpg: file changed as we read it
# tar: Test/57357.jpg: file changed as we read it
# tar: Test/57432.jpg: file changed as we read it
# tar: Test/57524.jpg: file changed as we read it
# tar: Test/57687.jpg: file changed as we read it
# tar: Test/57692.jpg: file changed as we read it
# tar: Test/57713.jpg: file changed as we read it
# tar: Test/57794.jpg: file changed as we read it
# tar: Test/57813.jpg: file changed as we read it
# tar: Test/57823.jpg: file changed as we read it
# tar: Test/57929.jpg: file changed as we read it
# tar: Test/57948.jpg: file changed as we read it
# tar: Test/57975.jpg: file changed as we read it
# tar: Test/58039.jpg: file changed as we read it
# tar: Test/58050.jpg: file changed as we read it
# tar: Test/58129.jpg: file changed as we read it
# tar: Test/58274.jpg: file changed as we read it
# tar: Test/58278.jpg: file changed as we read it
# tar: Test/58309.jpg: file changed as we read it
# tar: Test/58334.jpg: file changed as we read it
# tar: Test/58481.jpg: file changed as we read it
# tar: Test/58505.jpg: file changed as we read it
# tar: Test/58541.jpg: file changed as we read it
# tar: Test/58655.jpg: file changed as we read it
